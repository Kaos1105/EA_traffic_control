# %%
import libsumo as traci
import time
import csv
import os
import random, numpy as np
import pandas as pd, matplotlib.pyplot as plt
import csv, os
from datetime import datetime
from src import config

random.seed(config.SEED)
np.random.seed(config.SEED)

# %% [markdown]
# ## Simulation Section

# %%
from src.simulation_libs import find_avg_halt_range;
from src import config
from src import road_config

sumoCmd = [
    config.SUMO_BINARY,
    "-c", config.SUMO_CFG,
    "--seed", str(config.SEED),
]
traci.start(sumoCmd)
print(traci.trafficlight.getControlledLanes(road_config.TL_ID))
traci.simulationStep()
traci.simulation.saveState(config.SUMO_FIRST_STATE)
signal_state = traci.trafficlight.getRedYellowGreenState(road_config.TL_ID)
print(signal_state)

(max_avg_halt,min_avg_halt,max_fairness,min_fairness) = find_avg_halt_range(road_config.NS_LANES, road_config.EW_LANES)
print('Max avg halt', max_avg_halt)
print('Min avg halt', min_avg_halt)
print('Max fairness', max_fairness)
print('Min fairness', min_fairness)
traci.close()
# Out:
# ('1265822568#3_0', '1265822568#3_0', '1265822568#3_1', '1265822568#3_2', '1265822568#3_2', '1200728225#1_0', '1200728225#1_1', '1200728225#1_1', '1200728225#1_1', '1221994726#0_0', '1221994726#0_0', '1221994726#0_1')
# rrrrrGGggGGG
# ❌ Stopping at END_TIME.
# Max avg halt 17.192307692307693
# Min avg halt 1.935897435897436
# Max fairness 0.9999999710144937
# Min fairness 0.008219177857008826

# %%
from src.de_experiment import seed_mlp_controller_simulation
# Run the function
seed_mlp_controller_simulation()
# Out:
# /home/kaos/AfterGradEx/evolution_algo/EA_traffic_control/src/train_de_mlp.py:321: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(model_path, map_location=device)
# Time passed at cycle 1: 1.0s.
# === MLP Cycle 1 (t=1.0s) ===
# [MLP] split=0.598, C=83.6, O1=0.038, O2=0.026, score=0.034
#
# Time passed at cycle 2: 84.0s.
# === MLP Cycle 2 (t=84.0s) ===
# [MLP] split=0.579, C=86.2, O1=0.105, O2=0.277, score=0.156
#
# Time passed at cycle 3: 170.0s.
# === MLP Cycle 3 (t=170.0s) ===
# [MLP] split=0.567, C=86.1, O1=0.087, O2=0.084, score=0.086
#
# Time passed at cycle 4: 256.0s.
# === MLP Cycle 4 (t=256.0s) ===
# [MLP] split=0.571, C=85.5, O1=0.090, O2=0.305, score=0.154
#
# Time passed at cycle 5: 341.0s.
# === MLP Cycle 5 (t=341.0s) ===
# [MLP] split=0.569, C=84.5, O1=0.090, O2=0.074, score=0.086
#
# Time passed at cycle 6: 425.0s.
# === MLP Cycle 6 (t=425.0s) ===
# [MLP] split=0.563, C=84.1, O1=0.098, O2=0.113, score=0.103
#
# Time passed at cycle 7: 509.0s.
# === MLP Cycle 7 (t=509.0s) ===
# [MLP] split=0.560, C=84.0, O1=0.160, O2=0.369, score=0.223
#
# Time passed at cycle 8: 592.0s.
# === MLP Cycle 8 (t=592.0s) ===
# [MLP] split=0.543, C=84.1, O1=0.294, O2=0.814, score=0.450
#
# Time passed at cycle 9: 676.0s.
# === MLP Cycle 9 (t=676.0s) ===
# [MLP] split=0.594, C=88.4, O1=0.169, O2=0.608, score=0.301
#
# Time passed at cycle 10: 764.0s.
# === MLP Cycle 10 (t=764.0s) ===
# [MLP] split=0.566, C=83.2, O1=0.070, O2=0.014, score=0.053
#
# Time passed at cycle 11: 847.0s.
# === MLP Cycle 11 (t=847.0s) ===
# [MLP] split=0.577, C=82.2, O1=0.084, O2=0.229, score=0.128
#
# Time passed at cycle 12: 929.0s.
# === MLP Cycle 12 (t=929.0s) ===
# [MLP] split=0.581, C=83.1, O1=0.105, O2=0.096, score=0.102
#
# Time passed at cycle 13: 1012.0s.
# === MLP Cycle 13 (t=1012.0s) ===
# [MLP] split=0.567, C=82.8, O1=0.048, O2=0.117, score=0.069
#
# Time passed at cycle 14: 1094.0s.
# === MLP Cycle 14 (t=1094.0s) ===
# [MLP] split=0.583, C=82.4, O1=0.059, O2=0.188, score=0.098
#
# Time passed at cycle 15: 1176.0s.
# === MLP Cycle 15 (t=1176.0s) ===
# [MLP] split=0.576, C=82.9, O1=0.095, O2=0.183, score=0.122
#
# Time passed at cycle 16: 1258.0s.
# === MLP Cycle 16 (t=1258.0s) ===
# [MLP] split=0.571, C=83.5, O1=0.081, O2=0.249, score=0.132
#
# Time passed at cycle 17: 1341.0s.
# === MLP Cycle 17 (t=1341.0s) ===
# [MLP] split=0.571, C=83.1, O1=0.067, O2=0.340, score=0.149
#
# Time passed at cycle 18: 1424.0s.
# === MLP Cycle 18 (t=1424.0s) ===
# [MLP] split=0.573, C=82.8, O1=0.130, O2=0.508, score=0.243
#
# Time passed at cycle 19: 1506.0s.
# === MLP Cycle 19 (t=1506.0s) ===
# [MLP] split=0.583, C=84.3, O1=0.062, O2=0.059, score=0.061
#
# Time passed at cycle 20: 1590.0s.
# === MLP Cycle 20 (t=1590.0s) ===
# [MLP] split=0.580, C=83.6, O1=0.064, O2=0.038, score=0.056
#
# Time passed at cycle 21: 1673.0s.
# === MLP Cycle 21 (t=1673.0s) ===
# [MLP] split=0.578, C=83.6, O1=0.098, O2=0.446, score=0.203
#
# Time passed at cycle 22: 1756.0s.
# === MLP Cycle 22 (t=1756.0s) ===
# [MLP] split=0.568, C=83.4, O1=0.101, O2=0.200, score=0.131
#
# Time passed at cycle 23: 1839.0s.
# === MLP Cycle 23 (t=1839.0s) ===
# [MLP] split=0.559, C=83.5, O1=0.084, O2=0.331, score=0.158
#
# Time passed at cycle 24: 1922.0s.
# === MLP Cycle 24 (t=1922.0s) ===
# [MLP] split=0.577, C=83.2, O1=0.167, O2=0.187, score=0.173
#
# Time passed at cycle 25: 2005.0s.
# === MLP Cycle 25 (t=2005.0s) ===
# [MLP] split=0.560, C=85.8, O1=0.143, O2=0.087, score=0.126
#
# Time passed at cycle 26: 2090.0s.
# === MLP Cycle 26 (t=2090.0s) ===
# [MLP] split=0.554, C=84.4, O1=0.116, O2=0.287, score=0.167
#
# Time passed at cycle 27: 2174.0s.
# === MLP Cycle 27 (t=2174.0s) ===
# [MLP] split=0.566, C=82.2, O1=0.099, O2=0.380, score=0.183
#
# Time passed at cycle 28: 2256.0s.
# === MLP Cycle 28 (t=2256.0s) ===
# [MLP] split=0.564, C=81.9, O1=0.107, O2=0.172, score=0.127
#
# Time passed at cycle 29: 2337.0s.
# === MLP Cycle 29 (t=2337.0s) ===
# [MLP] split=0.555, C=82.5, O1=0.145, O2=0.074, score=0.124
#
# Time passed at cycle 30: 2419.0s.
# === MLP Cycle 30 (t=2419.0s) ===
# [MLP] split=0.544, C=84.4, O1=0.144, O2=0.658, score=0.298
#
# Time passed at cycle 31: 2503.0s.
# === MLP Cycle 31 (t=2503.0s) ===
# [MLP] split=0.556, C=80.8, O1=0.181, O2=0.312, score=0.221
#
# Time passed at cycle 32: 2583.0s.
# === MLP Cycle 32 (t=2583.0s) ===
# [MLP] split=0.559, C=86.0, O1=0.101, O2=0.262, score=0.149
#
# Time passed at cycle 33: 2669.0s.
# === MLP Cycle 33 (t=2669.0s) ===
# [MLP] split=0.564, C=81.3, O1=0.090, O2=0.184, score=0.118
#
# Time passed at cycle 34: 2750.0s.
# === MLP Cycle 34 (t=2750.0s) ===
# [MLP] split=0.564, C=82.0, O1=0.111, O2=0.294, score=0.166
#
# Time passed at cycle 35: 2832.0s.
# === MLP Cycle 35 (t=2832.0s) ===
# [MLP] split=0.557, C=82.1, O1=0.122, O2=0.218, score=0.151
#
# Time passed at cycle 36: 2914.0s.
# === MLP Cycle 36 (t=2914.0s) ===
# [MLP] split=0.549, C=82.7, O1=0.089, O2=0.199, score=0.122
#
# Time passed at cycle 37: 2996.0s.
# === MLP Cycle 37 (t=2996.0s) ===
# [MLP] split=0.559, C=82.0, O1=0.105, O2=0.369, score=0.184
#
# Time passed at cycle 38: 3077.0s.
# === MLP Cycle 38 (t=3077.0s) ===
# [MLP] split=0.576, C=83.4, O1=0.091, O2=0.270, score=0.144
#
# Time passed at cycle 39: 3160.0s.
# === MLP Cycle 39 (t=3160.0s) ===
# [MLP] split=0.577, C=83.3, O1=0.092, O2=0.018, score=0.070
#
# Time passed at cycle 40: 3243.0s.
# === MLP Cycle 40 (t=3243.0s) ===
# [MLP] split=0.569, C=83.1, O1=0.083, O2=0.321, score=0.154
#
# Time passed at cycle 41: 3326.0s.
# === MLP Cycle 41 (t=3326.0s) ===
# [MLP] split=0.572, C=82.8, O1=0.100, O2=0.105, score=0.102
#
# Time passed at cycle 42: 3408.0s.
# === MLP Cycle 42 (t=3408.0s) ===
# [MLP] split=0.561, C=83.3, O1=0.075, O2=0.046, score=0.066
#
# Time passed at cycle 43: 3491.0s.
# === MLP Cycle 43 (t=3491.0s) ===
# [MLP] split=0.569, C=82.8, O1=0.144, O2=0.435, score=0.231
#
# Time passed at cycle 44: 3573.0s.
# === MLP Cycle 44 (t=3573.0s) ===
# [MLP] split=0.585, C=84.5, O1=0.109, O2=0.253, score=0.152
#
# Time passed at cycle 45: 3657.0s.
# === MLP Cycle 45 (t=3657.0s) ===
# [MLP] split=0.585, C=83.2, O1=0.159, O2=0.219, score=0.177
#
# Time passed at cycle 46: 3740.0s.
# === MLP Cycle 46 (t=3740.0s) ===
# [MLP] split=0.586, C=84.4, O1=0.142, O2=0.017, score=0.104
#
# Time passed at cycle 47: 3824.0s.
# === MLP Cycle 47 (t=3824.0s) ===
# [MLP] split=0.568, C=84.1, O1=0.146, O2=0.127, score=0.140
#
# Time passed at cycle 48: 3908.0s.
# === MLP Cycle 48 (t=3908.0s) ===
# [MLP] split=0.563, C=83.7, O1=0.162, O2=0.140, score=0.156
#
# Time passed at cycle 49: 3991.0s.
# === MLP Cycle 49 (t=3991.0s) ===
# [MLP] split=0.555, C=83.8, O1=0.166, O2=0.151, score=0.162
#
# Time passed at cycle 50: 4074.0s.
# === MLP Cycle 50 (t=4074.0s) ===
# [MLP] split=0.557, C=83.5, O1=0.171, O2=0.468, score=0.260
#
# Time passed at cycle 51: 4157.0s.
# === MLP Cycle 51 (t=4157.0s) ===
# [MLP] split=0.558, C=80.7, O1=0.150, O2=0.091, score=0.133
#
# Time passed at cycle 52: 4237.0s.
# === MLP Cycle 52 (t=4237.0s) ===
# [MLP] split=0.557, C=84.5, O1=0.116, O2=0.372, score=0.193
#
# Time passed at cycle 53: 4321.0s.
# === MLP Cycle 53 (t=4321.0s) ===
# [MLP] split=0.593, C=83.2, O1=0.157, O2=0.144, score=0.153
#
# Time passed at cycle 54: 4404.0s.
# === MLP Cycle 54 (t=4404.0s) ===
# [MLP] split=0.578, C=83.0, O1=0.143, O2=0.182, score=0.155
#
# Time passed at cycle 55: 4487.0s.
# === MLP Cycle 55 (t=4487.0s) ===
# [MLP] split=0.563, C=82.4, O1=0.143, O2=0.143, score=0.143
#
# Time passed at cycle 56: 4569.0s.
# === MLP Cycle 56 (t=4569.0s) ===
# [MLP] split=0.572, C=84.5, O1=0.177, O2=0.390, score=0.241
#
# Time passed at cycle 57: 4653.0s.
# === MLP Cycle 57 (t=4653.0s) ===
# [MLP] split=0.618, C=84.2, O1=0.108, O2=0.207, score=0.138
#
# Time passed at cycle 58: 4737.0s.
# === MLP Cycle 58 (t=4737.0s) ===
# [MLP] split=0.583, C=81.9, O1=0.109, O2=0.273, score=0.158
#
# Time passed at cycle 59: 4818.0s.
# === MLP Cycle 59 (t=4818.0s) ===
# [MLP] split=0.570, C=82.2, O1=0.144, O2=0.112, score=0.135
#
# Time passed at cycle 60: 4900.0s.
# === MLP Cycle 60 (t=4900.0s) ===
# [MLP] split=0.565, C=84.7, O1=0.171, O2=0.281, score=0.204
#
# Time passed at cycle 61: 4984.0s.
# === MLP Cycle 61 (t=4984.0s) ===
# [MLP] split=0.591, C=84.6, O1=0.156, O2=0.506, score=0.261
#
# Time passed at cycle 62: 5068.0s.
# === MLP Cycle 62 (t=5068.0s) ===
# [MLP] split=0.641, C=84.4, O1=0.129, O2=0.163, score=0.139
#
# Time passed at cycle 63: 5152.0s.
# === MLP Cycle 63 (t=5152.0s) ===
# [MLP] split=0.585, C=81.5, O1=0.152, O2=0.212, score=0.170
#
# Time passed at cycle 64: 5233.0s.
# === MLP Cycle 64 (t=5233.0s) ===
# [MLP] split=0.564, C=82.7, O1=0.158, O2=0.363, score=0.220
#
# Time passed at cycle 65: 5315.0s.
# === MLP Cycle 65 (t=5315.0s) ===
# [MLP] split=0.558, C=81.9, O1=0.144, O2=0.014, score=0.105
#
# Time passed at cycle 66: 5396.0s.
# === MLP Cycle 66 (t=5396.0s) ===
# [MLP] split=0.554, C=84.7, O1=0.194, O2=0.341, score=0.238
#
# Time passed at cycle 67: 5480.0s.
# === MLP Cycle 67 (t=5480.0s) ===
# [MLP] split=0.583, C=85.2, O1=0.185, O2=0.529, score=0.289
#
# Time passed at cycle 68: 5565.0s.
# === MLP Cycle 68 (t=5565.0s) ===
# [MLP] split=0.644, C=84.5, O1=0.300, O2=0.137, score=0.251
#
# Time passed at cycle 69: 5649.0s.
# === MLP Cycle 69 (t=5649.0s) ===
# [MLP] split=0.612, C=84.8, O1=0.327, O2=0.267, score=0.309
#
# Time passed at cycle 70: 5733.0s.
# === MLP Cycle 70 (t=5733.0s) ===
# [MLP] split=0.563, C=83.8, O1=0.342, O2=0.220, score=0.306
#
# Time passed at cycle 71: 5816.0s.
# === MLP Cycle 71 (t=5816.0s) ===
# [MLP] split=0.576, C=85.8, O1=0.298, O2=0.091, score=0.236
#
# Time passed at cycle 72: 5901.0s.
# === MLP Cycle 72 (t=5901.0s) ===
# [MLP] split=0.575, C=84.4, O1=0.216, O2=0.045, score=0.164
#
# Time passed at cycle 73: 5985.0s.
# === MLP Cycle 73 (t=5985.0s) ===
# [MLP] split=0.580, C=84.4, O1=0.244, O2=0.242, score=0.244
#
# Time passed at cycle 74: 6069.0s.
# === MLP Cycle 74 (t=6069.0s) ===
# [MLP] split=0.607, C=84.9, O1=0.236, O2=0.255, score=0.242
#
# Time passed at cycle 75: 6153.0s.
# === MLP Cycle 75 (t=6153.0s) ===
# [MLP] split=0.635, C=85.7, O1=0.153, O2=0.202, score=0.168
#
# Time passed at cycle 76: 6238.0s.
# === MLP Cycle 76 (t=6238.0s) ===
# [MLP] split=0.667, C=87.5, O1=0.222, O2=0.318, score=0.251
#
# Time passed at cycle 77: 6325.0s.
# === MLP Cycle 77 (t=6325.0s) ===
# [MLP] split=0.572, C=80.8, O1=0.212, O2=0.051, score=0.164
#
# Time passed at cycle 78: 6405.0s.
# === MLP Cycle 78 (t=6405.0s) ===
# [MLP] split=0.572, C=85.3, O1=0.268, O2=0.309, score=0.280
#
# Time passed at cycle 79: 6490.0s.
# === MLP Cycle 79 (t=6490.0s) ===
# [MLP] split=0.608, C=86.6, O1=0.267, O2=0.172, score=0.238
#
# Time passed at cycle 80: 6576.0s.
# === MLP Cycle 80 (t=6576.0s) ===
# [MLP] split=0.615, C=86.0, O1=0.283, O2=0.183, score=0.253
#
# Time passed at cycle 81: 6661.0s.
# === MLP Cycle 81 (t=6661.0s) ===
# [MLP] split=0.581, C=83.1, O1=0.376, O2=0.355, score=0.370
#
# Time passed at cycle 82: 6744.0s.
# === MLP Cycle 82 (t=6744.0s) ===
# [MLP] split=0.575, C=83.6, O1=0.271, O2=0.084, score=0.215
#
# Time passed at cycle 83: 6827.0s.
# === MLP Cycle 83 (t=6827.0s) ===
# [MLP] split=0.576, C=83.8, O1=0.242, O2=0.129, score=0.208
#
# Time passed at cycle 84: 6910.0s.
# === MLP Cycle 84 (t=6910.0s) ===
# [MLP] split=0.578, C=83.7, O1=0.266, O2=0.231, score=0.256
#
# Time passed at cycle 85: 6993.0s.
# === MLP Cycle 85 (t=6993.0s) ===
# [MLP] split=0.574, C=82.9, O1=0.290, O2=0.196, score=0.262
#
# Time passed at cycle 86: 7075.0s.
# === MLP Cycle 86 (t=7075.0s) ===
# [MLP] split=0.570, C=83.3, O1=0.230, O2=0.004, score=0.162
#
# Time passed at cycle 87: 7158.0s.
# === MLP Cycle 87 (t=7158.0s) ===
# [MLP] split=0.576, C=84.3, O1=0.308, O2=0.059, score=0.233
#
# Time passed at cycle 88: 7242.0s.
# === MLP Cycle 88 (t=7242.0s) ===
# [MLP] split=0.576, C=84.8, O1=0.451, O2=0.201, score=0.376
#
# Time passed at cycle 89: 7326.0s.
# === MLP Cycle 89 (t=7326.0s) ===
# [MLP] split=0.552, C=88.4, O1=0.348, O2=0.098, score=0.273
#
# Time passed at cycle 90: 7414.0s.
# === MLP Cycle 90 (t=7414.0s) ===
# [MLP] split=0.554, C=86.2, O1=0.687, O2=0.518, score=0.637
#
# Time passed at cycle 91: 7500.0s.
# === MLP Cycle 91 (t=7500.0s) ===
# [MLP] split=0.554, C=89.8, O1=0.476, O2=0.050, score=0.348
#
# Time passed at cycle 92: 7589.0s.
# === MLP Cycle 92 (t=7589.0s) ===
# [MLP] split=0.567, C=87.2, O1=0.368, O2=0.064, score=0.277
#
# Time passed at cycle 93: 7676.0s.
# === MLP Cycle 93 (t=7676.0s) ===
# [MLP] split=0.587, C=81.6, O1=0.340, O2=0.012, score=0.242
#
# Time passed at cycle 94: 7757.0s.
# === MLP Cycle 94 (t=7757.0s) ===
# [MLP] split=0.604, C=80.6, O1=0.307, O2=0.047, score=0.229
#
# Time passed at cycle 95: 7837.0s.
# === MLP Cycle 95 (t=7837.0s) ===
# [MLP] split=0.614, C=80.3, O1=0.318, O2=0.088, score=0.249
#
# Time passed at cycle 96: 7917.0s.
# === MLP Cycle 96 (t=7917.0s) ===
# [MLP] split=0.616, C=80.2, O1=0.359, O2=0.106, score=0.283
#
# Time passed at cycle 97: 7997.0s.
# === MLP Cycle 97 (t=7997.0s) ===
# [MLP] split=0.617, C=80.2, O1=0.338, O2=0.002, score=0.237
#
# Time passed at cycle 98: 8077.0s.
# === MLP Cycle 98 (t=8077.0s) ===
# [MLP] split=0.614, C=80.7, O1=0.307, O2=0.017, score=0.220
#
# Time passed at cycle 99: 8157.0s.
# === MLP Cycle 99 (t=8157.0s) ===
# [MLP] split=0.603, C=81.0, O1=0.322, O2=0.098, score=0.255
#
# Time passed at cycle 100: 8238.0s.
# === MLP Cycle 100 (t=8238.0s) ===
# [MLP] split=0.596, C=81.8, O1=0.337, O2=0.142, score=0.279
#
# Time passed at cycle 101: 8319.0s.
# === MLP Cycle 101 (t=8319.0s) ===
# [MLP] split=0.592, C=82.0, O1=0.349, O2=0.106, score=0.276
#
# Time passed at cycle 102: 8401.0s.
# === MLP Cycle 102 (t=8401.0s) ===
# [MLP] split=0.581, C=83.1, O1=0.439, O2=0.106, score=0.340
#
# Time passed at cycle 103: 8484.0s.
# === MLP Cycle 103 (t=8484.0s) ===
# [MLP] split=0.568, C=86.4, O1=0.343, O2=0.020, score=0.246
#
# Time passed at cycle 104: 8570.0s.
# === MLP Cycle 104 (t=8570.0s) ===
# [MLP] split=0.571, C=83.8, O1=0.319, O2=0.096, score=0.252
#
# Time passed at cycle 105: 8653.0s.
# === MLP Cycle 105 (t=8653.0s) ===
# [MLP] split=0.584, C=82.9, O1=0.380, O2=0.199, score=0.326
#
# Time passed at cycle 106: 8735.0s.
# === MLP Cycle 106 (t=8735.0s) ===
# [MLP] split=0.587, C=82.6, O1=0.426, O2=0.147, score=0.342
#
# Time passed at cycle 107: 8817.0s.
# === MLP Cycle 107 (t=8817.0s) ===
# [MLP] split=0.584, C=83.4, O1=0.417, O2=0.115, score=0.326
#
# Time passed at cycle 108: 8900.0s.
# === MLP Cycle 108 (t=8900.0s) ===
# [MLP] split=0.600, C=83.5, O1=0.369, O2=0.047, score=0.272
#
# Time passed at cycle 109: 8983.0s.
# === MLP Cycle 109 (t=8983.0s) ===
# [MLP] split=0.598, C=81.8, O1=0.371, O2=0.159, score=0.308
#
# Time passed at cycle 110: 9064.0s.
# === MLP Cycle 110 (t=9064.0s) ===
# [MLP] split=0.596, C=81.5, O1=0.353, O2=0.097, score=0.276
#
# Time passed at cycle 111: 9145.0s.
# === MLP Cycle 111 (t=9145.0s) ===
# [MLP] split=0.597, C=81.3, O1=0.306, O2=0.126, score=0.252
#
# Time passed at cycle 112: 9226.0s.
# === MLP Cycle 112 (t=9226.0s) ===
# [MLP] split=0.596, C=81.6, O1=0.321, O2=0.031, score=0.234
#
# Time passed at cycle 113: 9307.0s.
# === MLP Cycle 113 (t=9307.0s) ===
# [MLP] split=0.596, C=81.9, O1=0.345, O2=0.355, score=0.348
#
# Time passed at cycle 114: 9388.0s.
# === MLP Cycle 114 (t=9388.0s) ===
# [MLP] split=0.586, C=82.0, O1=0.309, O2=0.119, score=0.252
#
# Time passed at cycle 115: 9469.0s.
# === MLP Cycle 115 (t=9469.0s) ===
# [MLP] split=0.582, C=82.3, O1=0.316, O2=0.030, score=0.230
#
# Time passed at cycle 116: 9551.0s.
# === MLP Cycle 116 (t=9551.0s) ===
# [MLP] split=0.577, C=83.8, O1=0.336, O2=0.068, score=0.256
#
# Time passed at cycle 117: 9634.0s.
# === MLP Cycle 117 (t=9634.0s) ===
# [MLP] split=0.571, C=84.3, O1=0.331, O2=0.129, score=0.270
#
# Time passed at cycle 118: 9718.0s.
# === MLP Cycle 118 (t=9718.0s) ===
# [MLP] split=0.580, C=83.1, O1=0.337, O2=0.001, score=0.236
#
# Time passed at cycle 119: 9801.0s.
# === MLP Cycle 119 (t=9801.0s) ===
# [MLP] split=0.579, C=84.4, O1=0.284, O2=0.084, score=0.224
#
# Time passed at cycle 120: 9885.0s.
# === MLP Cycle 120 (t=9885.0s) ===
# [MLP] split=0.586, C=83.1, O1=0.406, O2=0.196, score=0.343
#
# Time passed at cycle 121: 9968.0s.
# === MLP Cycle 121 (t=9968.0s) ===
# [MLP] split=0.573, C=83.9, O1=0.267, O2=0.020, score=0.193
#
# Time passed at cycle 122: 10051.0s.
# === MLP Cycle 122 (t=10051.0s) ===
# [MLP] split=0.587, C=83.1, O1=0.304, O2=0.084, score=0.238
#
# Time passed at cycle 123: 10134.0s.
# === MLP Cycle 123 (t=10134.0s) ===
# [MLP] split=0.590, C=82.6, O1=0.275, O2=0.048, score=0.207
#
# Time passed at cycle 124: 10216.0s.
# === MLP Cycle 124 (t=10216.0s) ===
# [MLP] split=0.589, C=82.6, O1=0.391, O2=0.148, score=0.318
#
# Time passed at cycle 125: 10298.0s.
# === MLP Cycle 125 (t=10298.0s) ===
# [MLP] split=0.575, C=84.4, O1=0.249, O2=0.089, score=0.201
#
# Time passed at cycle 126: 10382.0s.
# === MLP Cycle 126 (t=10382.0s) ===
# [MLP] split=0.594, C=83.7, O1=0.323, O2=0.024, score=0.234
#
# Time passed at cycle 127: 10465.0s.
# === MLP Cycle 127 (t=10465.0s) ===
# [MLP] split=0.592, C=83.1, O1=0.323, O2=0.097, score=0.255
#
# Time passed at cycle 128: 10548.0s.
# === MLP Cycle 128 (t=10548.0s) ===
# [MLP] split=0.591, C=82.4, O1=0.354, O2=0.167, score=0.298
#
# Time passed at cycle 129: 10630.0s.
# === MLP Cycle 129 (t=10630.0s) ===
# [MLP] split=0.583, C=83.1, O1=0.366, O2=0.081, score=0.281
#
# Time passed at cycle 130: 10713.0s.
# === MLP Cycle 130 (t=10713.0s) ===
# [MLP] split=0.575, C=84.7, O1=0.268, O2=0.064, score=0.207
#
# Time passed at cycle 131: 10797.0s.
# === MLP Cycle 131 (t=10797.0s) ===
# [MLP] split=0.588, C=83.0, O1=0.268, O2=0.149, score=0.232
#
# Time passed at cycle 132: 10880.0s.
# === MLP Cycle 132 (t=10880.0s) ===
# [MLP] split=0.587, C=82.9, O1=0.254, O2=0.027, score=0.186
#
# Time passed at cycle 133: 10962.0s.
# === MLP Cycle 133 (t=10962.0s) ===
# [MLP] split=0.585, C=83.3, O1=0.297, O2=0.004, score=0.209
#
# Time passed at cycle 134: 11045.0s.
# === MLP Cycle 134 (t=11045.0s) ===
# [MLP] split=0.580, C=83.6, O1=0.270, O2=0.098, score=0.219
#
# Time passed at cycle 135: 11128.0s.
# === MLP Cycle 135 (t=11128.0s) ===
# [MLP] split=0.583, C=83.0, O1=0.299, O2=0.112, score=0.243
#
# Time passed at cycle 136: 11211.0s.
# === MLP Cycle 136 (t=11211.0s) ===
# [MLP] split=0.580, C=82.9, O1=0.393, O2=0.310, score=0.368
#
# Time passed at cycle 137: 11293.0s.
# === MLP Cycle 137 (t=11293.0s) ===
# [MLP] split=0.581, C=83.2, O1=0.282, O2=0.088, score=0.224
#
# Time passed at cycle 138: 11376.0s.
# === MLP Cycle 138 (t=11376.0s) ===
# [MLP] split=0.579, C=82.6, O1=0.242, O2=0.033, score=0.179
#
# Time passed at cycle 139: 11458.0s.
# === MLP Cycle 139 (t=11458.0s) ===
# [MLP] split=0.579, C=83.5, O1=0.270, O2=0.007, score=0.191
#
# Time passed at cycle 140: 11541.0s.
# === MLP Cycle 140 (t=11541.0s) ===
# [MLP] split=0.578, C=83.4, O1=0.253, O2=0.015, score=0.181
#
# Time passed at cycle 141: 11624.0s.
# === MLP Cycle 141 (t=11624.0s) ===
# [MLP] split=0.580, C=83.5, O1=0.272, O2=0.108, score=0.223
#
# Time passed at cycle 142: 11707.0s.
# === MLP Cycle 142 (t=11707.0s) ===
# [MLP] split=0.579, C=83.2, O1=0.285, O2=0.267, score=0.280
#
# Time passed at cycle 143: 11790.0s.
# === MLP Cycle 143 (t=11790.0s) ===
# [MLP] split=0.577, C=82.8, O1=0.309, O2=0.141, score=0.258
#
# Time passed at cycle 144: 11872.0s.
# === MLP Cycle 144 (t=11872.0s) ===
# [MLP] split=0.573, C=85.2, O1=0.297, O2=0.031, score=0.217
#
# Time passed at cycle 145: 11957.0s.
# === MLP Cycle 145 (t=11957.0s) ===
# [MLP] split=0.577, C=84.3, O1=0.263, O2=0.242, score=0.257
#
# Time passed at cycle 146: 12041.0s.
# === MLP Cycle 146 (t=12041.0s) ===
# [MLP] split=0.580, C=83.1, O1=0.338, O2=0.252, score=0.312
#
# Time passed at cycle 147: 12124.0s.
# === MLP Cycle 147 (t=12124.0s) ===
# [MLP] split=0.576, C=82.9, O1=0.302, O2=0.144, score=0.255
#
# Time passed at cycle 148: 12206.0s.
# === MLP Cycle 148 (t=12206.0s) ===
# [MLP] split=0.574, C=84.4, O1=0.351, O2=0.206, score=0.308
#
# Time passed at cycle 149: 12290.0s.
# === MLP Cycle 149 (t=12290.0s) ===
# [MLP] split=0.567, C=85.6, O1=0.308, O2=0.077, score=0.239
#
# Time passed at cycle 150: 12375.0s.
# === MLP Cycle 150 (t=12375.0s) ===
# [MLP] split=0.578, C=83.8, O1=0.320, O2=0.100, score=0.254
#
# Time passed at cycle 151: 12458.0s.
# === MLP Cycle 151 (t=12458.0s) ===
# [MLP] split=0.581, C=83.1, O1=0.310, O2=0.107, score=0.249
#
# Time passed at cycle 152: 12541.0s.
# === MLP Cycle 152 (t=12541.0s) ===
# [MLP] split=0.580, C=83.5, O1=0.334, O2=0.193, score=0.292
#
# Time passed at cycle 153: 12624.0s.
# === MLP Cycle 153 (t=12624.0s) ===
# [MLP] split=0.583, C=83.6, O1=0.302, O2=0.120, score=0.247
#
# Time passed at cycle 154: 12707.0s.
# === MLP Cycle 154 (t=12707.0s) ===
# [MLP] split=0.587, C=82.8, O1=0.323, O2=0.214, score=0.290
#
# Time passed at cycle 155: 12789.0s.
# === MLP Cycle 155 (t=12789.0s) ===
# [MLP] split=0.582, C=82.6, O1=0.216, O2=0.141, score=0.194
#
# Time passed at cycle 156: 12871.0s.
# === MLP Cycle 156 (t=12871.0s) ===
# [MLP] split=0.588, C=84.3, O1=0.237, O2=0.009, score=0.169
#
# Time passed at cycle 157: 12955.0s.
# === MLP Cycle 157 (t=12955.0s) ===
# [MLP] split=0.580, C=83.9, O1=0.294, O2=0.103, score=0.237
#
# Time passed at cycle 158: 13038.0s.
# === MLP Cycle 158 (t=13038.0s) ===
# [MLP] split=0.578, C=83.6, O1=0.268, O2=0.048, score=0.202
#
# Time passed at cycle 159: 13121.0s.
# === MLP Cycle 159 (t=13121.0s) ===
# [MLP] split=0.579, C=83.8, O1=0.309, O2=0.284, score=0.301
#
# Time passed at cycle 160: 13204.0s.
# === MLP Cycle 160 (t=13204.0s) ===
# [MLP] split=0.575, C=82.5, O1=0.231, O2=0.104, score=0.193
#
# Time passed at cycle 161: 13286.0s.
# === MLP Cycle 161 (t=13286.0s) ===
# [MLP] split=0.580, C=84.7, O1=0.249, O2=0.004, score=0.175
#
# Time passed at cycle 162: 13370.0s.
# === MLP Cycle 162 (t=13370.0s) ===
# [MLP] split=0.579, C=84.4, O1=0.293, O2=0.446, score=0.339
#
# Time passed at cycle 163: 13454.0s.
# === MLP Cycle 163 (t=13454.0s) ===
# [MLP] split=0.627, C=85.2, O1=0.225, O2=0.283, score=0.242
#
# Time passed at cycle 164: 13539.0s.
# === MLP Cycle 164 (t=13539.0s) ===
# [MLP] split=0.664, C=86.3, O1=0.181, O2=0.351, score=0.232
#
# Time passed at cycle 165: 13625.0s.
# === MLP Cycle 165 (t=13625.0s) ===
# [MLP] split=0.688, C=87.4, O1=0.183, O2=0.247, score=0.202
#
# Time passed at cycle 166: 13712.0s.
# === MLP Cycle 166 (t=13712.0s) ===
# [MLP] split=0.685, C=86.9, O1=0.177, O2=0.443, score=0.257
#
# Time passed at cycle 167: 13798.0s.
# === MLP Cycle 167 (t=13798.0s) ===
# [MLP] split=0.688, C=87.0, O1=0.172, O2=0.568, score=0.291
#
# Time passed at cycle 168: 13884.0s.
# === MLP Cycle 168 (t=13884.0s) ===
# [MLP] split=0.688, C=87.1, O1=0.190, O2=0.154, score=0.179
#
# Time passed at cycle 169: 13971.0s.
# === MLP Cycle 169 (t=13971.0s) ===
# [MLP] split=0.680, C=85.0, O1=0.183, O2=0.009, score=0.131
#
# Time passed at cycle 170: 14055.0s.
# === MLP Cycle 170 (t=14055.0s) ===
# [MLP] split=0.652, C=83.9, O1=0.128, O2=0.052, score=0.105
#
# Time passed at cycle 171: 14138.0s.
# === MLP Cycle 171 (t=14138.0s) ===
# [MLP] split=0.650, C=85.3, O1=0.220, O2=0.288, score=0.240
#
# Time passed at cycle 172: 14223.0s.
# === MLP Cycle 172 (t=14223.0s) ===
# [MLP] split=0.656, C=84.8, O1=0.233, O2=0.408, score=0.286
#
# Time passed at cycle 173: 14307.0s.
# === MLP Cycle 173 (t=14307.0s) ===
# [MLP] split=0.679, C=85.1, O1=0.165, O2=0.229, score=0.184
#
# Time passed at cycle 174: 14392.0s.
# === MLP Cycle 174 (t=14392.0s) ===
# [MLP] split=0.685, C=86.0, O1=0.210, O2=0.008, score=0.149
#
# Time passed at cycle 175: 14477.0s.
# === MLP Cycle 175 (t=14477.0s) ===
# [MLP] split=0.638, C=83.0, O1=0.187, O2=0.191, score=0.188
#
# Time passed at cycle 176: 14559.0s.
# === MLP Cycle 176 (t=14559.0s) ===
# [MLP] split=0.659, C=86.1, O1=0.187, O2=0.797, score=0.370
#
# Time passed at cycle 177: 14645.0s.
# === MLP Cycle 177 (t=14645.0s) ===
# [MLP] split=0.688, C=86.8, O1=0.144, O2=0.285, score=0.186
#
# Time passed at cycle 178: 14731.0s.
# === MLP Cycle 178 (t=14731.0s) ===
# [MLP] split=0.688, C=85.9, O1=0.121, O2=0.049, score=0.100
#
# Time passed at cycle 179: 14816.0s.
# === MLP Cycle 179 (t=14816.0s) ===
# [MLP] split=0.656, C=83.7, O1=0.156, O2=0.314, score=0.204
#
# Time passed at cycle 180: 14899.0s.
# === MLP Cycle 180 (t=14899.0s) ===
# [MLP] split=0.592, C=81.6, O1=0.111, O2=0.797, score=0.317
#
# Time passed at cycle 181: 14980.0s.
# === MLP Cycle 181 (t=14980.0s) ===
# [MLP] split=0.577, C=81.7, O1=0.083, O2=0.055, score=0.075
#
# Time passed at cycle 182: 15061.0s.
# === MLP Cycle 182 (t=15061.0s) ===
# [MLP] split=0.572, C=82.5, O1=0.122, O2=0.263, score=0.165
#
# Time passed at cycle 183: 15143.0s.
# === MLP Cycle 183 (t=15143.0s) ===
# [MLP] split=0.559, C=82.3, O1=0.115, O2=0.728, score=0.299
#
# Time passed at cycle 184: 15225.0s.
# === MLP Cycle 184 (t=15225.0s) ===
# [MLP] split=0.561, C=81.5, O1=0.064, O2=0.011, score=0.048
#
# Time passed at cycle 185: 15306.0s.
# === MLP Cycle 185 (t=15306.0s) ===
# [MLP] split=0.565, C=82.1, O1=0.078, O2=0.307, score=0.147
#
# Time passed at cycle 186: 15388.0s.
# === MLP Cycle 186 (t=15388.0s) ===
# [MLP] split=0.575, C=82.9, O1=0.056, O2=0.083, score=0.064
#
# Time passed at cycle 187: 15470.0s.
# === MLP Cycle 187 (t=15470.0s) ===
# [MLP] split=0.574, C=82.8, O1=0.064, O2=0.051, score=0.060
#
# Time passed at cycle 188: 15552.0s.
# === MLP Cycle 188 (t=15552.0s) ===
# [MLP] split=0.573, C=83.1, O1=0.086, O2=0.215, score=0.125
#
# Time passed at cycle 189: 15635.0s.
# === MLP Cycle 189 (t=15635.0s) ===
# [MLP] split=0.566, C=83.3, O1=0.089, O2=0.083, score=0.087
#
# Time passed at cycle 190: 15718.0s.
# === MLP Cycle 190 (t=15718.0s) ===
# [MLP] split=0.566, C=83.6, O1=0.082, O2=0.277, score=0.141
#
# Time passed at cycle 191: 15801.0s.
# === MLP Cycle 191 (t=15801.0s) ===
# [MLP] split=0.568, C=82.9, O1=0.061, O2=0.045, score=0.056
#
# Time passed at cycle 192: 15883.0s.
# === MLP Cycle 192 (t=15883.0s) ===
# [MLP] split=0.572, C=82.9, O1=0.117, O2=0.467, score=0.222
#
# Time passed at cycle 193: 15965.0s.
# === MLP Cycle 193 (t=15965.0s) ===
# [MLP] split=0.582, C=84.1, O1=0.074, O2=0.242, score=0.124
#
# Time passed at cycle 194: 16049.0s.
# === MLP Cycle 194 (t=16049.0s) ===
# [MLP] split=0.583, C=83.7, O1=0.069, O2=0.200, score=0.108
#
# Time passed at cycle 195: 16132.0s.
# === MLP Cycle 195 (t=16132.0s) ===
# [MLP] split=0.578, C=83.5, O1=0.077, O2=0.052, score=0.069
#
# Time passed at cycle 196: 16215.0s.
# Elapsed time exceed at: cycle 196, stopping early.
#
# ✅ MLP simulation completed — results saved to logs/traffic_MLP_summary_20251209_124123.csv

# %%
from src import config
from src.utils import visualize_pow_results

visualize_pow_results(log_dir=config.LOG_DIR, suffix="20251209_124123", prefix="traffic_MLP")
# Out:
# Loaded 195 cycles from logs/traffic_MLP_summary_20251209_124123.csv
# === Summary statistics ===
#              s        C       O1       O2  score_best  elapsed_s
# count  195.000  195.000  195.000  195.000     195.000      195.0
# mean     0.587   83.650    0.217    0.190       0.209        0.0
# std      0.031    1.612    0.110    0.161       0.084        0.0
# min      0.543   80.200    0.038    0.001       0.034        0.0
# 25%      0.569   82.800    0.116    0.079       0.150        0.0
# 50%      0.579   83.500    0.212    0.147       0.217        0.0
# 75%      0.589   84.400    0.307    0.268       0.256        0.0
# max      0.688   89.800    0.687    0.814       0.637        0.0
#
# ✅  Average runtime per DE optimization: 0.00s
# ✅ Visualization complete — core PoW evidence generated.

# %%
from src.de_experiment import baseline_simulation

baseline_simulation()
# Out:
# Running baseline simulation: s=0.5, C=90s for 300 cycles
#
# Time passed at cycle 1: 1.0s.
# === Cycle 1 (t=1.0s) ===
# Vehicles currently in simulation: 1
# Fixed split=0.50, C=90.0, O1=0.073, O2=0.429, score=0.179
#
# Time passed at cycle 2: 91.0s.
# === Cycle 2 (t=91.0s) ===
# Vehicles currently in simulation: 17
# Fixed split=0.50, C=90.0, O1=0.147, O2=1.000, score=0.403
#
# Time passed at cycle 3: 181.0s.
# === Cycle 3 (t=181.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.104, O2=0.043, score=0.086
#
# Time passed at cycle 4: 271.0s.
# === Cycle 4 (t=271.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.076, O2=0.089, score=0.080
#
# Time passed at cycle 5: 361.0s.
# === Cycle 5 (t=361.0s) ===
# Vehicles currently in simulation: 15
# Fixed split=0.50, C=90.0, O1=0.138, O2=0.275, score=0.179
#
# Time passed at cycle 6: 451.0s.
# === Cycle 6 (t=451.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.112, O2=0.014, score=0.082
#
# Time passed at cycle 7: 541.0s.
# === Cycle 7 (t=541.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.131, O2=0.133, score=0.132
#
# Time passed at cycle 8: 631.0s.
# === Cycle 8 (t=631.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.079, O2=0.518, score=0.211
#
# Time passed at cycle 9: 721.0s.
# === Cycle 9 (t=721.0s) ===
# Vehicles currently in simulation: 16
# Fixed split=0.50, C=90.0, O1=0.159, O2=0.284, score=0.196
#
# Time passed at cycle 10: 811.0s.
# === Cycle 10 (t=811.0s) ===
# Vehicles currently in simulation: 15
# Fixed split=0.50, C=90.0, O1=0.144, O2=0.724, score=0.318
#
# Time passed at cycle 11: 901.0s.
# === Cycle 11 (t=901.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.070, O2=0.475, score=0.191
#
# Time passed at cycle 12: 991.0s.
# === Cycle 12 (t=991.0s) ===
# Vehicles currently in simulation: 16
# Fixed split=0.50, C=90.0, O1=0.077, O2=0.219, score=0.120
#
# Time passed at cycle 13: 1081.0s.
# === Cycle 13 (t=1081.0s) ===
# Vehicles currently in simulation: 18
# Fixed split=0.50, C=90.0, O1=0.097, O2=0.266, score=0.147
#
# Time passed at cycle 14: 1171.0s.
# === Cycle 14 (t=1171.0s) ===
# Vehicles currently in simulation: 16
# Fixed split=0.50, C=90.0, O1=0.100, O2=0.099, score=0.100
#
# Time passed at cycle 15: 1261.0s.
# === Cycle 15 (t=1261.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.079, O2=0.008, score=0.058
#
# Time passed at cycle 16: 1351.0s.
# === Cycle 16 (t=1351.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.144, O2=0.487, score=0.247
#
# Time passed at cycle 17: 1441.0s.
# === Cycle 17 (t=1441.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.093, O2=0.425, score=0.193
#
# Time passed at cycle 18: 1531.0s.
# === Cycle 18 (t=1531.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.073, O2=0.027, score=0.059
#
# Time passed at cycle 19: 1621.0s.
# === Cycle 19 (t=1621.0s) ===
# Vehicles currently in simulation: 16
# Fixed split=0.50, C=90.0, O1=0.147, O2=0.528, score=0.261
#
# Time passed at cycle 20: 1711.0s.
# === Cycle 20 (t=1711.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.117, O2=0.096, score=0.111
#
# Time passed at cycle 21: 1801.0s.
# === Cycle 21 (t=1801.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.083, O2=0.016, score=0.063
#
# Time passed at cycle 22: 1891.0s.
# === Cycle 22 (t=1891.0s) ===
# Vehicles currently in simulation: 18
# Fixed split=0.50, C=90.0, O1=0.219, O2=0.981, score=0.448
#
# Time passed at cycle 23: 1981.0s.
# === Cycle 23 (t=1981.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.207, O2=0.439, score=0.277
#
# Time passed at cycle 24: 2071.0s.
# === Cycle 24 (t=2071.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.088, O2=0.033, score=0.071
#
# Time passed at cycle 25: 2161.0s.
# === Cycle 25 (t=2161.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.101, O2=0.150, score=0.116
#
# Time passed at cycle 26: 2251.0s.
# === Cycle 26 (t=2251.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.137, O2=0.009, score=0.099
#
# Time passed at cycle 27: 2341.0s.
# === Cycle 27 (t=2341.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.102, O2=0.195, score=0.130
#
# Time passed at cycle 28: 2431.0s.
# === Cycle 28 (t=2431.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.177, O2=0.231, score=0.194
#
# Time passed at cycle 29: 2521.0s.
# === Cycle 29 (t=2521.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.174, O2=0.586, score=0.297
#
# Time passed at cycle 30: 2611.0s.
# === Cycle 30 (t=2611.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.146, O2=0.237, score=0.173
#
# Time passed at cycle 31: 2701.0s.
# === Cycle 31 (t=2701.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.149, O2=0.040, score=0.116
#
# Time passed at cycle 32: 2791.0s.
# === Cycle 32 (t=2791.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.118, O2=0.174, score=0.135
#
# Time passed at cycle 33: 2881.0s.
# === Cycle 33 (t=2881.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.092, O2=0.108, score=0.097
#
# Time passed at cycle 34: 2971.0s.
# === Cycle 34 (t=2971.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.140, O2=0.426, score=0.226
#
# Time passed at cycle 35: 3061.0s.
# === Cycle 35 (t=3061.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.136, O2=0.822, score=0.342
#
# Time passed at cycle 36: 3151.0s.
# === Cycle 36 (t=3151.0s) ===
# Vehicles currently in simulation: 23
# Fixed split=0.50, C=90.0, O1=0.065, O2=0.102, score=0.076
#
# Time passed at cycle 37: 3241.0s.
# === Cycle 37 (t=3241.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.124, O2=0.074, score=0.109
#
# Time passed at cycle 38: 3331.0s.
# === Cycle 38 (t=3331.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.234, O2=0.633, score=0.354
#
# Time passed at cycle 39: 3421.0s.
# === Cycle 39 (t=3421.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.136, O2=0.173, score=0.147
#
# Time passed at cycle 40: 3511.0s.
# === Cycle 40 (t=3511.0s) ===
# Vehicles currently in simulation: 24
# Fixed split=0.50, C=90.0, O1=0.118, O2=0.329, score=0.181
#
# Time passed at cycle 41: 3601.0s.
# === Cycle 41 (t=3601.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.139, O2=0.402, score=0.218
#
# Time passed at cycle 42: 3691.0s.
# === Cycle 42 (t=3691.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.117, O2=0.729, score=0.301
#
# Time passed at cycle 43: 3781.0s.
# === Cycle 43 (t=3781.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.126, O2=0.148, score=0.132
#
# Time passed at cycle 44: 3871.0s.
# === Cycle 44 (t=3871.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.138, O2=0.079, score=0.120
#
# Time passed at cycle 45: 3961.0s.
# === Cycle 45 (t=3961.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.158, O2=0.060, score=0.128
#
# Time passed at cycle 46: 4051.0s.
# === Cycle 46 (t=4051.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.112, O2=0.373, score=0.191
#
# Time passed at cycle 47: 4141.0s.
# === Cycle 47 (t=4141.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.174, O2=0.138, score=0.163
#
# Time passed at cycle 48: 4231.0s.
# === Cycle 48 (t=4231.0s) ===
# Vehicles currently in simulation: 32
# Fixed split=0.50, C=90.0, O1=0.232, O2=0.554, score=0.329
#
# Time passed at cycle 49: 4321.0s.
# === Cycle 49 (t=4321.0s) ===
# Vehicles currently in simulation: 33
# Fixed split=0.50, C=90.0, O1=0.110, O2=0.280, score=0.161
#
# Time passed at cycle 50: 4411.0s.
# === Cycle 50 (t=4411.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.186, O2=0.303, score=0.221
#
# Time passed at cycle 51: 4501.0s.
# === Cycle 51 (t=4501.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.203, O2=0.335, score=0.243
#
# Time passed at cycle 52: 4591.0s.
# === Cycle 52 (t=4591.0s) ===
# Vehicles currently in simulation: 33
# Fixed split=0.50, C=90.0, O1=0.266, O2=0.803, score=0.427
#
# Time passed at cycle 53: 4681.0s.
# === Cycle 53 (t=4681.0s) ===
# Vehicles currently in simulation: 36
# Fixed split=0.50, C=90.0, O1=0.235, O2=0.385, score=0.280
#
# Time passed at cycle 54: 4771.0s.
# === Cycle 54 (t=4771.0s) ===
# Vehicles currently in simulation: 34
# Fixed split=0.50, C=90.0, O1=0.155, O2=0.082, score=0.133
#
# Time passed at cycle 55: 4861.0s.
# === Cycle 55 (t=4861.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.189, O2=0.253, score=0.208
#
# Time passed at cycle 56: 4951.0s.
# === Cycle 56 (t=4951.0s) ===
# Vehicles currently in simulation: 34
# Fixed split=0.50, C=90.0, O1=0.193, O2=0.349, score=0.240
#
# Time passed at cycle 57: 5041.0s.
# === Cycle 57 (t=5041.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.157, O2=0.297, score=0.199
#
# Time passed at cycle 58: 5131.0s.
# === Cycle 58 (t=5131.0s) ===
# Vehicles currently in simulation: 32
# Fixed split=0.50, C=90.0, O1=0.116, O2=0.067, score=0.101
#
# Time passed at cycle 59: 5221.0s.
# === Cycle 59 (t=5221.0s) ===
# Vehicles currently in simulation: 23
# Fixed split=0.50, C=90.0, O1=0.119, O2=0.055, score=0.100
#
# Time passed at cycle 60: 5311.0s.
# === Cycle 60 (t=5311.0s) ===
# Vehicles currently in simulation: 23
# Fixed split=0.50, C=90.0, O1=0.176, O2=0.147, score=0.168
#
# Time passed at cycle 61: 5401.0s.
# === Cycle 61 (t=5401.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.241, O2=0.556, score=0.335
#
# Time passed at cycle 62: 5491.0s.
# === Cycle 62 (t=5491.0s) ===
# Vehicles currently in simulation: 43
# Fixed split=0.50, C=90.0, O1=0.372, O2=0.476, score=0.403
#
# Time passed at cycle 63: 5581.0s.
# === Cycle 63 (t=5581.0s) ===
# Vehicles currently in simulation: 50
# Fixed split=0.50, C=90.0, O1=0.382, O2=0.490, score=0.414
#
# Time passed at cycle 64: 5671.0s.
# === Cycle 64 (t=5671.0s) ===
# Vehicles currently in simulation: 54
# Fixed split=0.50, C=90.0, O1=0.288, O2=0.085, score=0.227
#
# Time passed at cycle 65: 5761.0s.
# === Cycle 65 (t=5761.0s) ===
# Vehicles currently in simulation: 51
# Fixed split=0.50, C=90.0, O1=0.363, O2=0.172, score=0.306
#
# Time passed at cycle 66: 5851.0s.
# === Cycle 66 (t=5851.0s) ===
# Vehicles currently in simulation: 55
# Fixed split=0.50, C=90.0, O1=0.359, O2=0.550, score=0.416
#
# Time passed at cycle 67: 5941.0s.
# === Cycle 67 (t=5941.0s) ===
# Vehicles currently in simulation: 53
# Fixed split=0.50, C=90.0, O1=0.278, O2=0.434, score=0.325
#
# Time passed at cycle 68: 6031.0s.
# === Cycle 68 (t=6031.0s) ===
# Vehicles currently in simulation: 41
# Fixed split=0.50, C=90.0, O1=0.395, O2=0.504, score=0.428
#
# Time passed at cycle 69: 6121.0s.
# === Cycle 69 (t=6121.0s) ===
# Vehicles currently in simulation: 52
# Fixed split=0.50, C=90.0, O1=0.321, O2=0.442, score=0.358
#
# Time passed at cycle 70: 6211.0s.
# === Cycle 70 (t=6211.0s) ===
# Vehicles currently in simulation: 46
# Fixed split=0.50, C=90.0, O1=0.305, O2=0.417, score=0.339
#
# Time passed at cycle 71: 6301.0s.
# === Cycle 71 (t=6301.0s) ===
# Vehicles currently in simulation: 48
# Fixed split=0.50, C=90.0, O1=0.322, O2=0.521, score=0.382
#
# Time passed at cycle 72: 6391.0s.
# === Cycle 72 (t=6391.0s) ===
# Vehicles currently in simulation: 52
# Fixed split=0.50, C=90.0, O1=0.429, O2=0.661, score=0.499
#
# Time passed at cycle 73: 6481.0s.
# === Cycle 73 (t=6481.0s) ===
# Vehicles currently in simulation: 53
# Fixed split=0.50, C=90.0, O1=0.434, O2=0.522, score=0.461
#
# Time passed at cycle 74: 6571.0s.
# === Cycle 74 (t=6571.0s) ===
# Vehicles currently in simulation: 59
# Fixed split=0.50, C=90.0, O1=0.282, O2=0.187, score=0.254
#
# Time passed at cycle 75: 6661.0s.
# === Cycle 75 (t=6661.0s) ===
# Vehicles currently in simulation: 52
# Fixed split=0.50, C=90.0, O1=0.307, O2=0.020, score=0.221
#
# Time passed at cycle 76: 6751.0s.
# === Cycle 76 (t=6751.0s) ===
# Vehicles currently in simulation: 50
# Fixed split=0.50, C=90.0, O1=0.324, O2=0.475, score=0.370
#
# Time passed at cycle 77: 6841.0s.
# === Cycle 77 (t=6841.0s) ===
# Vehicles currently in simulation: 37
# Fixed split=0.50, C=90.0, O1=0.284, O2=0.254, score=0.275
#
# Time passed at cycle 78: 6931.0s.
# === Cycle 78 (t=6931.0s) ===
# Vehicles currently in simulation: 45
# Fixed split=0.50, C=90.0, O1=0.248, O2=0.283, score=0.259
#
# Time passed at cycle 79: 7021.0s.
# === Cycle 79 (t=7021.0s) ===
# Vehicles currently in simulation: 42
# Fixed split=0.50, C=90.0, O1=0.241, O2=0.252, score=0.244
#
# Time passed at cycle 80: 7111.0s.
# === Cycle 80 (t=7111.0s) ===
# Vehicles currently in simulation: 40
# Fixed split=0.50, C=90.0, O1=0.365, O2=0.273, score=0.337
#
# Time passed at cycle 81: 7201.0s.
# === Cycle 81 (t=7201.0s) ===
# Vehicles currently in simulation: 49
# Fixed split=0.50, C=90.0, O1=0.488, O2=0.527, score=0.500
#
# Time passed at cycle 82: 7291.0s.
# === Cycle 82 (t=7291.0s) ===
# Vehicles currently in simulation: 82
# Fixed split=0.50, C=90.0, O1=0.573, O2=0.355, score=0.508
#
# Time passed at cycle 83: 7381.0s.
# === Cycle 83 (t=7381.0s) ===
# Vehicles currently in simulation: 96
# Fixed split=0.50, C=90.0, O1=0.360, O2=0.095, score=0.280
#
# Time passed at cycle 84: 7471.0s.
# === Cycle 84 (t=7471.0s) ===
# Vehicles currently in simulation: 80
# Fixed split=0.50, C=90.0, O1=0.325, O2=0.071, score=0.249
#
# Time passed at cycle 85: 7561.0s.
# === Cycle 85 (t=7561.0s) ===
# Vehicles currently in simulation: 97
# Fixed split=0.50, C=90.0, O1=0.320, O2=0.093, score=0.252
#
# Time passed at cycle 86: 7651.0s.
# === Cycle 86 (t=7651.0s) ===
# Vehicles currently in simulation: 112
# Fixed split=0.50, C=90.0, O1=0.369, O2=0.136, score=0.299
#
# Time passed at cycle 87: 7741.0s.
# === Cycle 87 (t=7741.0s) ===
# Vehicles currently in simulation: 127
# Fixed split=0.50, C=90.0, O1=0.361, O2=0.162, score=0.301
#
# Time passed at cycle 88: 7831.0s.
# === Cycle 88 (t=7831.0s) ===
# Vehicles currently in simulation: 122
# Fixed split=0.50, C=90.0, O1=0.308, O2=0.011, score=0.219
#
# Time passed at cycle 89: 7921.0s.
# === Cycle 89 (t=7921.0s) ===
# Vehicles currently in simulation: 119
# Fixed split=0.50, C=90.0, O1=0.376, O2=0.331, score=0.363
#
# Time passed at cycle 90: 8011.0s.
# === Cycle 90 (t=8011.0s) ===
# Vehicles currently in simulation: 124
# Fixed split=0.50, C=90.0, O1=0.374, O2=0.050, score=0.276
#
# Time passed at cycle 91: 8101.0s.
# === Cycle 91 (t=8101.0s) ===
# Vehicles currently in simulation: 118
# Fixed split=0.50, C=90.0, O1=0.332, O2=0.043, score=0.245
#
# Time passed at cycle 92: 8191.0s.
# === Cycle 92 (t=8191.0s) ===
# Vehicles currently in simulation: 104
# Fixed split=0.50, C=90.0, O1=0.263, O2=0.078, score=0.208
#
# Time passed at cycle 93: 8281.0s.
# === Cycle 93 (t=8281.0s) ===
# Vehicles currently in simulation: 108
# Fixed split=0.50, C=90.0, O1=0.331, O2=0.043, score=0.244
#
# Time passed at cycle 94: 8371.0s.
# === Cycle 94 (t=8371.0s) ===
# Vehicles currently in simulation: 115
# Fixed split=0.50, C=90.0, O1=0.468, O2=0.329, score=0.427
#
# Time passed at cycle 95: 8461.0s.
# === Cycle 95 (t=8461.0s) ===
# Vehicles currently in simulation: 130
# Fixed split=0.50, C=90.0, O1=0.537, O2=0.312, score=0.469
#
# Time passed at cycle 96: 8551.0s.
# === Cycle 96 (t=8551.0s) ===
# Vehicles currently in simulation: 147
# Fixed split=0.50, C=90.0, O1=0.557, O2=0.468, score=0.530
#
# Time passed at cycle 97: 8641.0s.
# === Cycle 97 (t=8641.0s) ===
# Vehicles currently in simulation: 151
# Fixed split=0.50, C=90.0, O1=0.559, O2=0.371, score=0.503
#
# Time passed at cycle 98: 8731.0s.
# === Cycle 98 (t=8731.0s) ===
# Vehicles currently in simulation: 153
# Fixed split=0.50, C=90.0, O1=0.509, O2=0.224, score=0.424
#
# Time passed at cycle 99: 8821.0s.
# === Cycle 99 (t=8821.0s) ===
# Vehicles currently in simulation: 151
# Fixed split=0.50, C=90.0, O1=0.433, O2=0.206, score=0.365
#
# Time passed at cycle 100: 8911.0s.
# === Cycle 100 (t=8911.0s) ===
# Vehicles currently in simulation: 136
# Fixed split=0.50, C=90.0, O1=0.346, O2=0.122, score=0.279
#
# Time passed at cycle 101: 9001.0s.
# === Cycle 101 (t=9001.0s) ===
# Vehicles currently in simulation: 132
# Fixed split=0.50, C=90.0, O1=0.359, O2=0.214, score=0.316
#
# Time passed at cycle 102: 9091.0s.
# === Cycle 102 (t=9091.0s) ===
# Vehicles currently in simulation: 136
# Fixed split=0.50, C=90.0, O1=0.339, O2=0.283, score=0.322
#
# Time passed at cycle 103: 9181.0s.
# === Cycle 103 (t=9181.0s) ===
# Vehicles currently in simulation: 126
# Fixed split=0.50, C=90.0, O1=0.356, O2=0.342, score=0.351
#
# Time passed at cycle 104: 9271.0s.
# === Cycle 104 (t=9271.0s) ===
# Vehicles currently in simulation: 135
# Fixed split=0.50, C=90.0, O1=0.317, O2=0.096, score=0.251
#
# Time passed at cycle 105: 9361.0s.
# === Cycle 105 (t=9361.0s) ===
# Vehicles currently in simulation: 129
# Fixed split=0.50, C=90.0, O1=0.356, O2=0.296, score=0.338
#
# Time passed at cycle 106: 9451.0s.
# === Cycle 106 (t=9451.0s) ===
# Vehicles currently in simulation: 137
# Fixed split=0.50, C=90.0, O1=0.335, O2=0.117, score=0.270
#
# Time passed at cycle 107: 9541.0s.
# === Cycle 107 (t=9541.0s) ===
# Vehicles currently in simulation: 131
# Fixed split=0.50, C=90.0, O1=0.418, O2=0.220, score=0.359
#
# Time passed at cycle 108: 9631.0s.
# === Cycle 108 (t=9631.0s) ===
# Vehicles currently in simulation: 135
# Fixed split=0.50, C=90.0, O1=0.421, O2=0.223, score=0.362
#
# Time passed at cycle 109: 9721.0s.
# === Cycle 109 (t=9721.0s) ===
# Vehicles currently in simulation: 136
# Fixed split=0.50, C=90.0, O1=0.298, O2=0.080, score=0.233
#
# Time passed at cycle 110: 9811.0s.
# === Cycle 110 (t=9811.0s) ===
# Vehicles currently in simulation: 130
# Fixed split=0.50, C=90.0, O1=0.378, O2=0.128, score=0.303
#
# Time passed at cycle 111: 9901.0s.
# === Cycle 111 (t=9901.0s) ===
# Vehicles currently in simulation: 137
# Fixed split=0.50, C=90.0, O1=0.309, O2=0.231, score=0.286
#
# Time passed at cycle 112: 9991.0s.
# === Cycle 112 (t=9991.0s) ===
# Vehicles currently in simulation: 132
# Fixed split=0.50, C=90.0, O1=0.297, O2=0.102, score=0.239
#
# Time passed at cycle 113: 10081.0s.
# === Cycle 113 (t=10081.0s) ===
# Vehicles currently in simulation: 120
# Fixed split=0.50, C=90.0, O1=0.462, O2=0.459, score=0.461
#
# Time passed at cycle 114: 10171.0s.
# === Cycle 114 (t=10171.0s) ===
# Vehicles currently in simulation: 140
# Fixed split=0.50, C=90.0, O1=0.329, O2=0.266, score=0.310
#
# Time passed at cycle 115: 10261.0s.
# === Cycle 115 (t=10261.0s) ===
# Vehicles currently in simulation: 130
# Fixed split=0.50, C=90.0, O1=0.448, O2=0.428, score=0.442
#
# Time passed at cycle 116: 10351.0s.
# === Cycle 116 (t=10351.0s) ===
# Vehicles currently in simulation: 110
# Fixed split=0.50, C=90.0, O1=0.381, O2=0.152, score=0.313
#
# Time passed at cycle 117: 10441.0s.
# === Cycle 117 (t=10441.0s) ===
# Vehicles currently in simulation: 98
# Fixed split=0.50, C=90.0, O1=0.355, O2=0.162, score=0.297
#
# Time passed at cycle 118: 10531.0s.
# === Cycle 118 (t=10531.0s) ===
# Vehicles currently in simulation: 100
# Fixed split=0.50, C=90.0, O1=0.398, O2=0.185, score=0.334
#
# Time passed at cycle 119: 10621.0s.
# === Cycle 119 (t=10621.0s) ===
# Vehicles currently in simulation: 96
# Fixed split=0.50, C=90.0, O1=0.419, O2=0.197, score=0.352
#
# Time passed at cycle 120: 10711.0s.
# === Cycle 120 (t=10711.0s) ===
# Vehicles currently in simulation: 108
# Fixed split=0.50, C=90.0, O1=0.357, O2=0.283, score=0.335
#
# Time passed at cycle 121: 10801.0s.
# === Cycle 121 (t=10801.0s) ===
# Vehicles currently in simulation: 92
# Fixed split=0.50, C=90.0, O1=0.340, O2=0.111, score=0.271
#
# Time passed at cycle 122: 10891.0s.
# === Cycle 122 (t=10891.0s) ===
# Vehicles currently in simulation: 91
# Fixed split=0.50, C=90.0, O1=0.360, O2=0.246, score=0.326
#
# Time passed at cycle 123: 10981.0s.
# === Cycle 123 (t=10981.0s) ===
# Vehicles currently in simulation: 70
# Fixed split=0.50, C=90.0, O1=0.236, O2=0.062, score=0.184
#
# Time passed at cycle 124: 11071.0s.
# === Cycle 124 (t=11071.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.290, O2=0.074, score=0.225
#
# Time passed at cycle 125: 11161.0s.
# === Cycle 125 (t=11161.0s) ===
# Vehicles currently in simulation: 75
# Fixed split=0.50, C=90.0, O1=0.254, O2=0.022, score=0.184
#
# Time passed at cycle 126: 11251.0s.
# === Cycle 126 (t=11251.0s) ===
# Vehicles currently in simulation: 65
# Fixed split=0.50, C=90.0, O1=0.324, O2=0.157, score=0.274
#
# Time passed at cycle 127: 11341.0s.
# === Cycle 127 (t=11341.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.330, O2=0.110, score=0.264
#
# Time passed at cycle 128: 11431.0s.
# === Cycle 128 (t=11431.0s) ===
# Vehicles currently in simulation: 80
# Fixed split=0.50, C=90.0, O1=0.366, O2=0.345, score=0.360
#
# Time passed at cycle 129: 11521.0s.
# === Cycle 129 (t=11521.0s) ===
# Vehicles currently in simulation: 78
# Fixed split=0.50, C=90.0, O1=0.335, O2=0.196, score=0.293
#
# Time passed at cycle 130: 11611.0s.
# === Cycle 130 (t=11611.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.379, O2=0.524, score=0.423
#
# Time passed at cycle 131: 11701.0s.
# === Cycle 131 (t=11701.0s) ===
# Vehicles currently in simulation: 81
# Fixed split=0.50, C=90.0, O1=0.296, O2=0.555, score=0.374
#
# Time passed at cycle 132: 11791.0s.
# === Cycle 132 (t=11791.0s) ===
# Vehicles currently in simulation: 73
# Fixed split=0.50, C=90.0, O1=0.344, O2=0.495, score=0.390
#
# Time passed at cycle 133: 11881.0s.
# === Cycle 133 (t=11881.0s) ===
# Vehicles currently in simulation: 70
# Fixed split=0.50, C=90.0, O1=0.430, O2=0.479, score=0.445
#
# Time passed at cycle 134: 11971.0s.
# === Cycle 134 (t=11971.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.327, O2=0.544, score=0.392
#
# Time passed at cycle 135: 12061.0s.
# === Cycle 135 (t=12061.0s) ===
# Vehicles currently in simulation: 67
# Fixed split=0.50, C=90.0, O1=0.400, O2=0.630, score=0.469
#
# Time passed at cycle 136: 12151.0s.
# === Cycle 136 (t=12151.0s) ===
# Vehicles currently in simulation: 73
# Fixed split=0.50, C=90.0, O1=0.315, O2=0.492, score=0.368
#
# Time passed at cycle 137: 12241.0s.
# === Cycle 137 (t=12241.0s) ===
# Vehicles currently in simulation: 74
# Fixed split=0.50, C=90.0, O1=0.363, O2=0.576, score=0.427
#
# Time passed at cycle 138: 12331.0s.
# === Cycle 138 (t=12331.0s) ===
# Vehicles currently in simulation: 59
# Fixed split=0.50, C=90.0, O1=0.248, O2=0.672, score=0.375
#
# Time passed at cycle 139: 12421.0s.
# === Cycle 139 (t=12421.0s) ===
# Vehicles currently in simulation: 68
# Fixed split=0.50, C=90.0, O1=0.344, O2=0.374, score=0.353
#
# Time passed at cycle 140: 12511.0s.
# === Cycle 140 (t=12511.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.309, O2=0.910, score=0.490
#
# Time passed at cycle 141: 12601.0s.
# === Cycle 141 (t=12601.0s) ===
# Vehicles currently in simulation: 64
# Fixed split=0.50, C=90.0, O1=0.214, O2=0.296, score=0.239
#
# Time passed at cycle 142: 12691.0s.
# === Cycle 142 (t=12691.0s) ===
# Vehicles currently in simulation: 59
# Fixed split=0.50, C=90.0, O1=0.331, O2=0.970, score=0.523
#
# Time passed at cycle 143: 12781.0s.
# === Cycle 143 (t=12781.0s) ===
# Vehicles currently in simulation: 71
# Fixed split=0.50, C=90.0, O1=0.293, O2=0.633, score=0.395
#
# Time passed at cycle 144: 12871.0s.
# === Cycle 144 (t=12871.0s) ===
# Vehicles currently in simulation: 76
# Fixed split=0.50, C=90.0, O1=0.320, O2=0.681, score=0.428
#
# Time passed at cycle 145: 12961.0s.
# === Cycle 145 (t=12961.0s) ===
# Vehicles currently in simulation: 79
# Fixed split=0.50, C=90.0, O1=0.320, O2=0.483, score=0.369
#
# Time passed at cycle 146: 13051.0s.
# === Cycle 146 (t=13051.0s) ===
# Vehicles currently in simulation: 83
# Fixed split=0.50, C=90.0, O1=0.289, O2=0.308, score=0.295
#
# Time passed at cycle 147: 13141.0s.
# === Cycle 147 (t=13141.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.259, O2=0.429, score=0.310
#
# Time passed at cycle 148: 13231.0s.
# === Cycle 148 (t=13231.0s) ===
# Vehicles currently in simulation: 59
# Fixed split=0.50, C=90.0, O1=0.284, O2=0.407, score=0.321
#
# Time passed at cycle 149: 13321.0s.
# === Cycle 149 (t=13321.0s) ===
# Vehicles currently in simulation: 62
# Fixed split=0.50, C=90.0, O1=0.335, O2=0.702, score=0.445
#
# Time passed at cycle 150: 13411.0s.
# === Cycle 150 (t=13411.0s) ===
# Vehicles currently in simulation: 62
# Fixed split=0.50, C=90.0, O1=0.275, O2=0.697, score=0.401
#
# Time passed at cycle 151: 13501.0s.
# === Cycle 151 (t=13501.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.362, O2=0.662, score=0.452
#
# Time passed at cycle 152: 13591.0s.
# === Cycle 152 (t=13591.0s) ===
# Vehicles currently in simulation: 70
# Fixed split=0.50, C=90.0, O1=0.368, O2=0.600, score=0.437
#
# Time passed at cycle 153: 13681.0s.
# === Cycle 153 (t=13681.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.401, O2=0.653, score=0.477
#
# Time passed at cycle 154: 13771.0s.
# === Cycle 154 (t=13771.0s) ===
# Vehicles currently in simulation: 74
# Fixed split=0.50, C=90.0, O1=0.359, O2=0.690, score=0.459
#
# Time passed at cycle 155: 13861.0s.
# === Cycle 155 (t=13861.0s) ===
# Vehicles currently in simulation: 73
# Fixed split=0.50, C=90.0, O1=0.264, O2=0.526, score=0.343
#
# Time passed at cycle 156: 13951.0s.
# === Cycle 156 (t=13951.0s) ===
# Vehicles currently in simulation: 68
# Fixed split=0.50, C=90.0, O1=0.296, O2=0.538, score=0.368
#
# Time passed at cycle 157: 14041.0s.
# === Cycle 157 (t=14041.0s) ===
# Vehicles currently in simulation: 50
# Fixed split=0.50, C=90.0, O1=0.271, O2=0.446, score=0.324
#
# Time passed at cycle 158: 14131.0s.
# === Cycle 158 (t=14131.0s) ===
# Vehicles currently in simulation: 43
# Fixed split=0.50, C=90.0, O1=0.385, O2=0.650, score=0.464
#
# Time passed at cycle 159: 14221.0s.
# === Cycle 159 (t=14221.0s) ===
# Vehicles currently in simulation: 39
# Fixed split=0.50, C=90.0, O1=0.383, O2=0.663, score=0.467
#
# Time passed at cycle 160: 14311.0s.
# === Cycle 160 (t=14311.0s) ===
# Vehicles currently in simulation: 38
# Fixed split=0.50, C=90.0, O1=0.238, O2=0.774, score=0.399
#
# Time passed at cycle 161: 14401.0s.
# === Cycle 161 (t=14401.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.258, O2=0.390, score=0.298
#
# Time passed at cycle 162: 14491.0s.
# === Cycle 162 (t=14491.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.340, O2=0.895, score=0.507
#
# Time passed at cycle 163: 14581.0s.
# === Cycle 163 (t=14581.0s) ===
# Vehicles currently in simulation: 34
# Fixed split=0.50, C=90.0, O1=0.322, O2=0.604, score=0.407
#
# Time passed at cycle 164: 14671.0s.
# === Cycle 164 (t=14671.0s) ===
# Vehicles currently in simulation: 36
# Fixed split=0.50, C=90.0, O1=0.336, O2=0.631, score=0.424
#
# Time passed at cycle 165: 14761.0s.
# === Cycle 165 (t=14761.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.274, O2=0.678, score=0.395
#
# Time passed at cycle 166: 14851.0s.
# === Cycle 166 (t=14851.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.229, O2=0.365, score=0.269
#
# Time passed at cycle 167: 14941.0s.
# === Cycle 167 (t=14941.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.139, O2=0.116, score=0.132
#
# Time passed at cycle 168: 15031.0s.
# === Cycle 168 (t=15031.0s) ===
# Vehicles currently in simulation: 24
# Fixed split=0.50, C=90.0, O1=0.245, O2=0.464, score=0.311
#
# Time passed at cycle 169: 15121.0s.
# === Cycle 169 (t=15121.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.217, O2=0.228, score=0.220
#
# Time passed at cycle 170: 15211.0s.
# === Cycle 170 (t=15211.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.277, O2=0.509, score=0.346
#
# Time passed at cycle 171: 15301.0s.
# === Cycle 171 (t=15301.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.287, O2=0.631, score=0.390
#
# Time passed at cycle 172: 15391.0s.
# === Cycle 172 (t=15391.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.316, O2=0.532, score=0.381
#
# Time passed at cycle 173: 15481.0s.
# === Cycle 173 (t=15481.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.292, O2=0.474, score=0.346
#
# Time passed at cycle 174: 15571.0s.
# === Cycle 174 (t=15571.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.220, O2=0.643, score=0.347
#
# Time passed at cycle 175: 15661.0s.
# === Cycle 175 (t=15661.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.224, O2=0.484, score=0.302
#
# Time passed at cycle 176: 15751.0s.
# === Cycle 176 (t=15751.0s) ===
# Vehicles currently in simulation: 24
# Fixed split=0.50, C=90.0, O1=0.337, O2=0.691, score=0.443
#
# Time passed at cycle 177: 15841.0s.
# === Cycle 177 (t=15841.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.274, O2=0.780, score=0.426
#
# Time passed at cycle 178: 15931.0s.
# === Cycle 178 (t=15931.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.259, O2=0.853, score=0.437
#
# Time passed at cycle 179: 16021.0s.
# === Cycle 179 (t=16021.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.287, O2=0.631, score=0.390
#
# Time passed at cycle 180: 16111.0s.
# === Cycle 180 (t=16111.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.303, O2=0.755, score=0.439
#
# Time passed at cycle 181: 16201.0s.
# ❌ No more vehicles at cycle 181, stopping early.
#
# ✅ Baseline completed — results saved to logs/traffic_baseline_summary_20251209_124215.csv

# %%
from src import config
from src.utils import visualize_pow_results

visualize_pow_results(log_dir=config.LOG_DIR, prefix="traffic_baseline", suffix="20251209_124215")
# Out:
# Loaded 180 cycles from logs/traffic_baseline_summary_20251209_124215.csv
# === Summary statistics ===
#            s      C       O1       O2  score_best  elapsed_s
# count  180.0  180.0  180.000  180.000     180.000      180.0
# mean     0.5   90.0    0.270    0.359       0.296        0.0
# std      0.0    0.0    0.115    0.241       0.119        0.0
# min      0.5   90.0    0.065    0.008       0.058        0.0
# 25%      0.5   90.0    0.158    0.148       0.211        0.0
# 50%      0.5   90.0    0.288    0.330       0.302        0.0
# 75%      0.5   90.0    0.355    0.526       0.390        0.0
# max      0.5   90.0    0.573    1.000       0.530        0.0
#
# ✅  Average runtime per DE optimization: 0.00s
# ✅ Visualization complete — core PoW evidence generated.

# %%
from src.utils import compare_logs_by_time

compare_logs_by_time(baseline_prefix='traffic_baseline', de_prefix ='traffic_MLP', de_suffix='20251209_124123', baseline_suffix='20251209_124215')

# %%
from src.utils import compare_score_best

compare_score_best(baseline_prefix='traffic_baseline', de_prefix ='traffic_MLP', de_suffix='20251209_124123', baseline_suffix='20251209_124215')
# Out:
# Average DE score_best: 0.2163
# Average Baseline score_best: 0.2964
# Δ Improvement: -0.0800 (-27.00% change)
# ✅ DE improves over Baseline.
