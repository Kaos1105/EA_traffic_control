# %%
import libsumo as traci
import time
import csv
import os
import random, numpy as np
import pandas as pd, matplotlib.pyplot as plt
import csv, os
from datetime import datetime
from src import config

random.seed(config.SEED)
np.random.seed(config.SEED)

# %% [markdown]
# ## Simulation Section

# %%
from src.simulation_libs import find_avg_halt_range;
from src import config
from src import road_config

sumoCmd = [
    config.SUMO_BINARY,
    "-c", config.SUMO_CFG,
    "--seed", str(config.SEED),
]
traci.start(sumoCmd)
print(traci.trafficlight.getControlledLanes(road_config.TL_ID))
traci.simulationStep()
traci.simulation.saveState(config.SUMO_FIRST_STATE)
signal_state = traci.trafficlight.getRedYellowGreenState(road_config.TL_ID)
print(signal_state)

(max_avg_halt,min_avg_halt,max_fairness,min_fairness) = find_avg_halt_range(road_config.NS_LANES, road_config.EW_LANES)
print('Max avg halt', max_avg_halt)
print('Min avg halt', min_avg_halt)
print('Max fairness', max_fairness)
print('Min fairness', min_fairness)
traci.close()
# Out:
# ('1265822568#3_0', '1265822568#3_0', '1265822568#3_1', '1265822568#3_2', '1265822568#3_2', '1200728225#1_0', '1200728225#1_1', '1200728225#1_1', '1200728225#1_1', '1221994726#0_0', '1221994726#0_0', '1221994726#0_1')
# rrrrrGGggGGG
# ❌ Stopping at END_TIME.
# Max avg halt 30.076923076923077
# Min avg halt 2.2564102564102564
# Max fairness 0.9297124303606253
# Min fairness 0.0

# %%
from src.de_experiment import seed_mlp_controller_simulation
# Run the function
seed_mlp_controller_simulation()
# Out:
# Time passed at cycle 1: 1.0s.
# === MLP Cycle 1 (t=1.0s) ===
# [MLP] split=0.598, C=83.6, O1=0.049, O2=0.123, score=0.071
#
# Time passed at cycle 2: 84.0s.
# === MLP Cycle 2 (t=84.0s) ===
# [MLP] split=0.578, C=86.3, O1=0.134, O2=0.916, score=0.369
#
# Time passed at cycle 3: 170.0s.
# === MLP Cycle 3 (t=170.0s) ===
# [MLP] split=0.601, C=85.7, O1=0.174, O2=0.104, score=0.153
#
# Time passed at cycle 4: 255.0s.
# === MLP Cycle 4 (t=255.0s) ===
# /home/kaos/AfterGradEx/evolution_algo/EA_traffic_control/src/train_de_mlp.py:321: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(model_path, map_location=device)
# [MLP] split=0.550, C=88.1, O1=0.146, O2=0.259, score=0.180
#
# Time passed at cycle 5: 343.0s.
# === MLP Cycle 5 (t=343.0s) ===
# [MLP] split=0.551, C=85.3, O1=0.107, O2=0.022, score=0.081
#
# Time passed at cycle 6: 428.0s.
# === MLP Cycle 6 (t=428.0s) ===
# [MLP] split=0.560, C=84.4, O1=0.263, O2=0.648, score=0.378
#
# Time passed at cycle 7: 512.0s.
# === MLP Cycle 7 (t=512.0s) ===
# [MLP] split=0.608, C=86.6, O1=0.162, O2=0.146, score=0.157
#
# Time passed at cycle 8: 598.0s.
# === MLP Cycle 8 (t=598.0s) ===
# [MLP] split=0.580, C=82.9, O1=0.127, O2=0.463, score=0.228
#
# Time passed at cycle 9: 680.0s.
# === MLP Cycle 9 (t=680.0s) ===
# [MLP] split=0.575, C=82.2, O1=0.140, O2=0.400, score=0.218
#
# Time passed at cycle 10: 762.0s.
# === MLP Cycle 10 (t=762.0s) ===
# [MLP] split=0.602, C=83.8, O1=0.091, O2=0.129, score=0.102
#
# Time passed at cycle 11: 845.0s.
# === MLP Cycle 11 (t=845.0s) ===
# [MLP] split=0.576, C=82.1, O1=0.129, O2=0.203, score=0.151
#
# Time passed at cycle 12: 927.0s.
# === MLP Cycle 12 (t=927.0s) ===
# [MLP] split=0.561, C=83.0, O1=0.116, O2=0.312, score=0.175
#
# Time passed at cycle 13: 1009.0s.
# === MLP Cycle 13 (t=1009.0s) ===
# [MLP] split=0.562, C=82.1, O1=0.110, O2=0.170, score=0.128
#
# Time passed at cycle 14: 1091.0s.
# === MLP Cycle 14 (t=1091.0s) ===
# [MLP] split=0.569, C=83.7, O1=0.123, O2=0.248, score=0.160
#
# Time passed at cycle 15: 1174.0s.
# === MLP Cycle 15 (t=1174.0s) ===
# [MLP] split=0.577, C=83.7, O1=0.139, O2=0.359, score=0.205
#
# Time passed at cycle 16: 1257.0s.
# === MLP Cycle 16 (t=1257.0s) ===
# [MLP] split=0.600, C=83.6, O1=0.080, O2=0.049, score=0.071
#
# Time passed at cycle 17: 1340.0s.
# === MLP Cycle 17 (t=1340.0s) ===
# [MLP] split=0.583, C=82.8, O1=0.130, O2=0.231, score=0.161
#
# Time passed at cycle 18: 1422.0s.
# === MLP Cycle 18 (t=1422.0s) ===
# [MLP] split=0.566, C=83.1, O1=0.108, O2=0.121, score=0.112
#
# Time passed at cycle 19: 1505.0s.
# === MLP Cycle 19 (t=1505.0s) ===
# [MLP] split=0.563, C=83.1, O1=0.126, O2=0.215, score=0.153
#
# Time passed at cycle 20: 1588.0s.
# === MLP Cycle 20 (t=1588.0s) ===
# [MLP] split=0.574, C=84.3, O1=0.113, O2=0.444, score=0.212
#
# Time passed at cycle 21: 1672.0s.
# === MLP Cycle 21 (t=1672.0s) ===
# [MLP] split=0.602, C=83.8, O1=0.108, O2=0.445, score=0.209
#
# Time passed at cycle 22: 1755.0s.
# === MLP Cycle 22 (t=1755.0s) ===
# [MLP] split=0.611, C=83.7, O1=0.140, O2=0.319, score=0.194
#
# Time passed at cycle 23: 1838.0s.
# === MLP Cycle 23 (t=1838.0s) ===
# [MLP] split=0.568, C=82.9, O1=0.101, O2=0.119, score=0.106
#
# Time passed at cycle 24: 1920.0s.
# === MLP Cycle 24 (t=1920.0s) ===
# [MLP] split=0.575, C=83.5, O1=0.142, O2=0.496, score=0.248
#
# Time passed at cycle 25: 2003.0s.
# === MLP Cycle 25 (t=2003.0s) ===
# [MLP] split=0.609, C=84.0, O1=0.131, O2=0.187, score=0.148
#
# Time passed at cycle 26: 2087.0s.
# === MLP Cycle 26 (t=2087.0s) ===
# [MLP] split=0.597, C=82.5, O1=0.180, O2=0.272, score=0.207
#
# Time passed at cycle 27: 2169.0s.
# === MLP Cycle 27 (t=2169.0s) ===
# [MLP] split=0.560, C=83.3, O1=0.131, O2=0.283, score=0.177
#
# Time passed at cycle 28: 2252.0s.
# === MLP Cycle 28 (t=2252.0s) ===
# [MLP] split=0.563, C=82.1, O1=0.166, O2=0.110, score=0.149
#
# Time passed at cycle 29: 2334.0s.
# === MLP Cycle 29 (t=2334.0s) ===
# [MLP] split=0.556, C=85.7, O1=0.117, O2=0.248, score=0.156
#
# Time passed at cycle 30: 2419.0s.
# === MLP Cycle 30 (t=2419.0s) ===
# [MLP] split=0.567, C=81.4, O1=0.109, O2=0.466, score=0.216
#
# Time passed at cycle 31: 2500.0s.
# === MLP Cycle 31 (t=2500.0s) ===
# [MLP] split=0.594, C=83.7, O1=0.120, O2=0.092, score=0.111
#
# Time passed at cycle 32: 2583.0s.
# === MLP Cycle 32 (t=2583.0s) ===
# [MLP] split=0.564, C=81.9, O1=0.116, O2=0.093, score=0.109
#
# Time passed at cycle 33: 2664.0s.
# === MLP Cycle 33 (t=2664.0s) ===
# [MLP] split=0.562, C=83.4, O1=0.129, O2=0.024, score=0.097
#
# Time passed at cycle 34: 2747.0s.
# === MLP Cycle 34 (t=2747.0s) ===
# [MLP] split=0.560, C=84.5, O1=0.098, O2=0.076, score=0.092
#
# Time passed at cycle 35: 2831.0s.
# === MLP Cycle 35 (t=2831.0s) ===
# [MLP] split=0.575, C=82.9, O1=0.140, O2=0.388, score=0.215
#
# Time passed at cycle 36: 2913.0s.
# === MLP Cycle 36 (t=2913.0s) ===
# [MLP] split=0.601, C=83.8, O1=0.100, O2=0.208, score=0.132
#
# Time passed at cycle 37: 2996.0s.
# === MLP Cycle 37 (t=2996.0s) ===
# [MLP] split=0.575, C=82.1, O1=0.140, O2=0.155, score=0.145
#
# Time passed at cycle 38: 3078.0s.
# === MLP Cycle 38 (t=3078.0s) ===
# [MLP] split=0.573, C=84.4, O1=0.144, O2=0.109, score=0.133
#
# Time passed at cycle 39: 3162.0s.
# === MLP Cycle 39 (t=3162.0s) ===
# [MLP] split=0.560, C=83.4, O1=0.129, O2=0.173, score=0.142
#
# Time passed at cycle 40: 3245.0s.
# === MLP Cycle 40 (t=3245.0s) ===
# [MLP] split=0.578, C=84.2, O1=0.099, O2=0.073, score=0.091
#
# Time passed at cycle 41: 3329.0s.
# === MLP Cycle 41 (t=3329.0s) ===
# [MLP] split=0.579, C=82.8, O1=0.119, O2=0.102, score=0.114
#
# Time passed at cycle 42: 3411.0s.
# === MLP Cycle 42 (t=3411.0s) ===
# [MLP] split=0.577, C=83.1, O1=0.156, O2=0.017, score=0.114
#
# Time passed at cycle 43: 3494.0s.
# === MLP Cycle 43 (t=3494.0s) ===
# [MLP] split=0.558, C=84.7, O1=0.125, O2=0.120, score=0.124
#
# Time passed at cycle 44: 3578.0s.
# === MLP Cycle 44 (t=3578.0s) ===
# [MLP] split=0.568, C=82.6, O1=0.115, O2=0.289, score=0.167
#
# Time passed at cycle 45: 3660.0s.
# === MLP Cycle 45 (t=3660.0s) ===
# [MLP] split=0.567, C=81.7, O1=0.245, O2=0.308, score=0.264
#
# Time passed at cycle 46: 3741.0s.
# === MLP Cycle 46 (t=3741.0s) ===
# [MLP] split=0.567, C=88.5, O1=0.178, O2=0.050, score=0.140
#
# Time passed at cycle 47: 3829.0s.
# === MLP Cycle 47 (t=3829.0s) ===
# [MLP] split=0.573, C=86.1, O1=0.179, O2=0.180, score=0.179
#
# Time passed at cycle 48: 3915.0s.
# === MLP Cycle 48 (t=3915.0s) ===
# [MLP] split=0.569, C=83.3, O1=0.181, O2=0.220, score=0.193
#
# Time passed at cycle 49: 3998.0s.
# === MLP Cycle 49 (t=3998.0s) ===
# [MLP] split=0.563, C=82.9, O1=0.158, O2=0.375, score=0.223
#
# Time passed at cycle 50: 4080.0s.
# === MLP Cycle 50 (t=4080.0s) ===
# [MLP] split=0.563, C=80.6, O1=0.204, O2=0.210, score=0.206
#
# Time passed at cycle 51: 4160.0s.
# === MLP Cycle 51 (t=4160.0s) ===
# [MLP] split=0.551, C=83.3, O1=0.142, O2=0.184, score=0.155
#
# Time passed at cycle 52: 4243.0s.
# === MLP Cycle 52 (t=4243.0s) ===
# [MLP] split=0.571, C=83.4, O1=0.124, O2=0.080, score=0.111
#
# Time passed at cycle 53: 4326.0s.
# === MLP Cycle 53 (t=4326.0s) ===
# [MLP] split=0.565, C=82.0, O1=0.225, O2=0.243, score=0.230
#
# Time passed at cycle 54: 4407.0s.
# === MLP Cycle 54 (t=4407.0s) ===
# [MLP] split=0.571, C=87.2, O1=0.176, O2=0.360, score=0.231
#
# Time passed at cycle 55: 4494.0s.
# === MLP Cycle 55 (t=4494.0s) ===
# [MLP] split=0.631, C=84.2, O1=0.106, O2=0.154, score=0.120
#
# Time passed at cycle 56: 4578.0s.
# === MLP Cycle 56 (t=4578.0s) ===
# [MLP] split=0.599, C=82.5, O1=0.139, O2=0.246, score=0.171
#
# Time passed at cycle 57: 4660.0s.
# === MLP Cycle 57 (t=4660.0s) ===
# [MLP] split=0.569, C=81.3, O1=0.163, O2=0.046, score=0.128
#
# Time passed at cycle 58: 4741.0s.
# === MLP Cycle 58 (t=4741.0s) ===
# [MLP] split=0.560, C=85.3, O1=0.197, O2=0.253, score=0.214
#
# Time passed at cycle 59: 4826.0s.
# === MLP Cycle 59 (t=4826.0s) ===
# [MLP] split=0.591, C=85.8, O1=0.184, O2=0.186, score=0.184
#
# Time passed at cycle 60: 4911.0s.
# === MLP Cycle 60 (t=4911.0s) ===
# [MLP] split=0.622, C=84.9, O1=0.197, O2=0.145, score=0.182
#
# Time passed at cycle 61: 4995.0s.
# === MLP Cycle 61 (t=4995.0s) ===
# [MLP] split=0.574, C=81.8, O1=0.204, O2=0.270, score=0.224
#
# Time passed at cycle 62: 5076.0s.
# === MLP Cycle 62 (t=5076.0s) ===
# [MLP] split=0.562, C=83.0, O1=0.300, O2=0.337, score=0.311
#
# Time passed at cycle 63: 5159.0s.
# === MLP Cycle 63 (t=5159.0s) ===
# [MLP] split=0.552, C=84.0, O1=0.185, O2=0.021, score=0.136
#
# Time passed at cycle 64: 5242.0s.
# === MLP Cycle 64 (t=5242.0s) ===
# [MLP] split=0.571, C=84.4, O1=0.270, O2=0.252, score=0.265
#
# Time passed at cycle 65: 5326.0s.
# === MLP Cycle 65 (t=5326.0s) ===
# [MLP] split=0.582, C=87.4, O1=0.315, O2=0.299, score=0.310
#
# Time passed at cycle 66: 5413.0s.
# === MLP Cycle 66 (t=5413.0s) ===
# [MLP] split=0.584, C=87.7, O1=0.369, O2=0.282, score=0.343
#
# Time passed at cycle 67: 5500.0s.
# === MLP Cycle 67 (t=5500.0s) ===
# [MLP] split=0.580, C=87.7, O1=0.375, O2=0.198, score=0.322
#
# Time passed at cycle 68: 5587.0s.
# === MLP Cycle 68 (t=5587.0s) ===
# [MLP] split=0.577, C=86.3, O1=0.341, O2=0.001, score=0.239
#
# Time passed at cycle 69: 5673.0s.
# === MLP Cycle 69 (t=5673.0s) ===
# [MLP] split=0.580, C=85.7, O1=0.367, O2=0.169, score=0.307
#
# Time passed at cycle 70: 5758.0s.
# === MLP Cycle 70 (t=5758.0s) ===
# [MLP] split=0.595, C=83.0, O1=0.374, O2=0.117, score=0.297
#
# Time passed at cycle 71: 5841.0s.
# === MLP Cycle 71 (t=5841.0s) ===
# [MLP] split=0.599, C=83.0, O1=0.353, O2=0.024, score=0.254
#
# Time passed at cycle 72: 5923.0s.
# === MLP Cycle 72 (t=5923.0s) ===
# [MLP] split=0.594, C=82.8, O1=0.348, O2=0.114, score=0.278
#
# Time passed at cycle 73: 6005.0s.
# === MLP Cycle 73 (t=6005.0s) ===
# [MLP] split=0.588, C=82.3, O1=0.320, O2=0.459, score=0.361
#
# Time passed at cycle 74: 6087.0s.
# === MLP Cycle 74 (t=6087.0s) ===
# [MLP] split=0.642, C=83.3, O1=0.218, O2=0.035, score=0.163
#
# Time passed at cycle 75: 6170.0s.
# === MLP Cycle 75 (t=6170.0s) ===
# [MLP] split=0.645, C=82.8, O1=0.338, O2=0.083, score=0.262
#
# Time passed at cycle 76: 6252.0s.
# === MLP Cycle 76 (t=6252.0s) ===
# [MLP] split=0.616, C=80.3, O1=0.383, O2=0.117, score=0.303
#
# Time passed at cycle 77: 6332.0s.
# === MLP Cycle 77 (t=6332.0s) ===
# [MLP] split=0.602, C=82.1, O1=0.305, O2=0.012, score=0.217
#
# Time passed at cycle 78: 6414.0s.
# === MLP Cycle 78 (t=6414.0s) ===
# [MLP] split=0.599, C=81.5, O1=0.333, O2=0.039, score=0.245
#
# Time passed at cycle 79: 6495.0s.
# === MLP Cycle 79 (t=6495.0s) ===
# [MLP] split=0.599, C=82.3, O1=0.325, O2=0.126, score=0.265
#
# Time passed at cycle 80: 6577.0s.
# === MLP Cycle 80 (t=6577.0s) ===
# [MLP] split=0.595, C=82.4, O1=0.261, O2=0.019, score=0.189
#
# Time passed at cycle 81: 6659.0s.
# === MLP Cycle 81 (t=6659.0s) ===
# [MLP] split=0.592, C=82.6, O1=0.261, O2=0.027, score=0.191
#
# Time passed at cycle 82: 6741.0s.
# === MLP Cycle 82 (t=6741.0s) ===
# [MLP] split=0.589, C=83.0, O1=0.327, O2=0.160, score=0.277
#
# Time passed at cycle 83: 6823.0s.
# === MLP Cycle 83 (t=6823.0s) ===
# [MLP] split=0.585, C=82.8, O1=0.370, O2=0.143, score=0.302
#
# Time passed at cycle 84: 6905.0s.
# === MLP Cycle 84 (t=6905.0s) ===
# [MLP] split=0.571, C=84.8, O1=0.375, O2=0.107, score=0.294
#
# Time passed at cycle 85: 6989.0s.
# === MLP Cycle 85 (t=6989.0s) ===
# [MLP] split=0.582, C=84.9, O1=0.260, O2=0.042, score=0.194
#
# Time passed at cycle 86: 7073.0s.
# === MLP Cycle 86 (t=7073.0s) ===
# [MLP] split=0.588, C=83.2, O1=0.378, O2=0.127, score=0.303
#
# Time passed at cycle 87: 7156.0s.
# === MLP Cycle 87 (t=7156.0s) ===
# [MLP] split=0.592, C=83.7, O1=0.293, O2=0.259, score=0.283
#
# Time passed at cycle 88: 7239.0s.
# === MLP Cycle 88 (t=7239.0s) ===
# [MLP] split=0.583, C=82.3, O1=0.540, O2=0.297, score=0.467
#
# Time passed at cycle 89: 7321.0s.
# === MLP Cycle 89 (t=7321.0s) ===
# [MLP] split=0.551, C=87.7, O1=0.456, O2=0.179, score=0.373
#
# Time passed at cycle 90: 7408.0s.
# === MLP Cycle 90 (t=7408.0s) ===
# [MLP] split=0.546, C=86.4, O1=0.455, O2=0.072, score=0.340
#
# Time passed at cycle 91: 7494.0s.
# === MLP Cycle 91 (t=7494.0s) ===
# [MLP] split=0.553, C=88.0, O1=0.482, O2=0.126, score=0.375
#
# Time passed at cycle 92: 7581.0s.
# === MLP Cycle 92 (t=7581.0s) ===
# [MLP] split=0.556, C=85.2, O1=0.422, O2=0.138, score=0.337
#
# Time passed at cycle 93: 7666.0s.
# === MLP Cycle 93 (t=7666.0s) ===
# [MLP] split=0.569, C=82.6, O1=0.475, O2=0.280, score=0.417
#
# Time passed at cycle 94: 7748.0s.
# === MLP Cycle 94 (t=7748.0s) ===
# [MLP] split=0.586, C=81.6, O1=0.400, O2=0.151, score=0.326
#
# Time passed at cycle 95: 7829.0s.
# === MLP Cycle 95 (t=7829.0s) ===
# [MLP] split=0.605, C=80.3, O1=0.393, O2=0.070, score=0.296
#
# Time passed at cycle 96: 7909.0s.
# === MLP Cycle 96 (t=7909.0s) ===
# [MLP] split=0.624, C=79.1, O1=0.388, O2=0.020, score=0.278
#
# Time passed at cycle 97: 7988.0s.
# === MLP Cycle 97 (t=7988.0s) ===
# [MLP] split=0.631, C=78.8, O1=0.365, O2=0.099, score=0.285
#
# Time passed at cycle 98: 8066.0s.
# === MLP Cycle 98 (t=8066.0s) ===
# [MLP] split=0.629, C=78.8, O1=0.485, O2=0.265, score=0.419
#
# Time passed at cycle 99: 8144.0s.
# === MLP Cycle 99 (t=8144.0s) ===
# [MLP] split=0.626, C=79.4, O1=0.290, O2=0.001, score=0.203
#
# Time passed at cycle 100: 8223.0s.
# === MLP Cycle 100 (t=8223.0s) ===
# [MLP] split=0.636, C=78.9, O1=0.289, O2=0.045, score=0.216
#
# Time passed at cycle 101: 8301.0s.
# === MLP Cycle 101 (t=8301.0s) ===
# [MLP] split=0.626, C=79.3, O1=0.363, O2=0.231, score=0.323
#
# Time passed at cycle 102: 8380.0s.
# === MLP Cycle 102 (t=8380.0s) ===
# [MLP] split=0.628, C=81.1, O1=0.362, O2=0.236, score=0.324
#
# Time passed at cycle 103: 8461.0s.
# === MLP Cycle 103 (t=8461.0s) ===
# [MLP] split=0.632, C=80.9, O1=0.436, O2=0.219, score=0.371
#
# Time passed at cycle 104: 8541.0s.
# === MLP Cycle 104 (t=8541.0s) ===
# [MLP] split=0.627, C=79.7, O1=0.361, O2=0.091, score=0.280
#
# Time passed at cycle 105: 8620.0s.
# === MLP Cycle 105 (t=8620.0s) ===
# [MLP] split=0.642, C=79.2, O1=0.334, O2=0.210, score=0.297
#
# Time passed at cycle 106: 8699.0s.
# === MLP Cycle 106 (t=8699.0s) ===
# [MLP] split=0.656, C=80.4, O1=0.307, O2=0.157, score=0.262
#
# Time passed at cycle 107: 8779.0s.
# === MLP Cycle 107 (t=8779.0s) ===
# [MLP] split=0.664, C=79.9, O1=0.371, O2=0.101, score=0.290
#
# Time passed at cycle 108: 8858.0s.
# === MLP Cycle 108 (t=8858.0s) ===
# [MLP] split=0.664, C=77.7, O1=0.344, O2=0.056, score=0.258
#
# Time passed at cycle 109: 8935.0s.
# === MLP Cycle 109 (t=8935.0s) ===
# [MLP] split=0.656, C=76.9, O1=0.341, O2=0.156, score=0.285
#
# Time passed at cycle 110: 9011.0s.
# === MLP Cycle 110 (t=9011.0s) ===
# [MLP] split=0.624, C=78.9, O1=0.407, O2=0.149, score=0.329
#
# Time passed at cycle 111: 9089.0s.
# === MLP Cycle 111 (t=9089.0s) ===
# [MLP] split=0.611, C=81.2, O1=0.465, O2=0.406, score=0.447
#
# Time passed at cycle 112: 9170.0s.
# === MLP Cycle 112 (t=9170.0s) ===
# [MLP] split=0.604, C=82.7, O1=0.483, O2=0.387, score=0.454
#
# Time passed at cycle 113: 9252.0s.
# === MLP Cycle 113 (t=9252.0s) ===
# [MLP] split=0.609, C=82.1, O1=0.340, O2=0.045, score=0.252
#
# Time passed at cycle 114: 9334.0s.
# === MLP Cycle 114 (t=9334.0s) ===
# [MLP] split=0.638, C=79.3, O1=0.311, O2=0.091, score=0.245
#
# Time passed at cycle 115: 9413.0s.
# === MLP Cycle 115 (t=9413.0s) ===
# [MLP] split=0.647, C=78.2, O1=0.312, O2=0.022, score=0.225
#
# Time passed at cycle 116: 9491.0s.
# === MLP Cycle 116 (t=9491.0s) ===
# [MLP] split=0.640, C=78.5, O1=0.372, O2=0.211, score=0.324
#
# Time passed at cycle 117: 9569.0s.
# === MLP Cycle 117 (t=9569.0s) ===
# [MLP] split=0.614, C=80.7, O1=0.263, O2=0.068, score=0.205
#
# Time passed at cycle 118: 9649.0s.
# === MLP Cycle 118 (t=9649.0s) ===
# [MLP] split=0.597, C=82.5, O1=0.271, O2=0.002, score=0.191
#
# Time passed at cycle 119: 9731.0s.
# === MLP Cycle 119 (t=9731.0s) ===
# [MLP] split=0.588, C=82.7, O1=0.303, O2=0.002, score=0.213
#
# Time passed at cycle 120: 9813.0s.
# === MLP Cycle 120 (t=9813.0s) ===
# [MLP] split=0.583, C=83.2, O1=0.335, O2=0.095, score=0.263
#
# Time passed at cycle 121: 9896.0s.
# === MLP Cycle 121 (t=9896.0s) ===
# [MLP] split=0.587, C=83.1, O1=0.341, O2=0.132, score=0.278
#
# Time passed at cycle 122: 9979.0s.
# === MLP Cycle 122 (t=9979.0s) ===
# [MLP] split=0.579, C=83.5, O1=0.351, O2=0.162, score=0.295
#
# Time passed at cycle 123: 10062.0s.
# === MLP Cycle 123 (t=10062.0s) ===
# [MLP] split=0.577, C=83.7, O1=0.417, O2=0.156, score=0.339
#
# Time passed at cycle 124: 10145.0s.
# === MLP Cycle 124 (t=10145.0s) ===
# [MLP] split=0.567, C=85.1, O1=0.388, O2=0.195, score=0.330
#
# Time passed at cycle 125: 10230.0s.
# === MLP Cycle 125 (t=10230.0s) ===
# [MLP] split=0.573, C=83.8, O1=0.333, O2=0.130, score=0.272
#
# Time passed at cycle 126: 10313.0s.
# === MLP Cycle 126 (t=10313.0s) ===
# [MLP] split=0.591, C=82.9, O1=0.271, O2=0.069, score=0.210
#
# Time passed at cycle 127: 10395.0s.
# === MLP Cycle 127 (t=10395.0s) ===
# [MLP] split=0.607, C=82.3, O1=0.383, O2=0.238, score=0.340
#
# Time passed at cycle 128: 10477.0s.
# === MLP Cycle 128 (t=10477.0s) ===
# [MLP] split=0.598, C=82.6, O1=0.372, O2=0.333, score=0.360
#
# Time passed at cycle 129: 10559.0s.
# === MLP Cycle 129 (t=10559.0s) ===
# [MLP] split=0.589, C=82.1, O1=0.353, O2=0.044, score=0.260
#
# Time passed at cycle 130: 10641.0s.
# === MLP Cycle 130 (t=10641.0s) ===
# [MLP] split=0.580, C=84.4, O1=0.338, O2=0.098, score=0.266
#
# Time passed at cycle 131: 10725.0s.
# === MLP Cycle 131 (t=10725.0s) ===
# [MLP] split=0.584, C=82.7, O1=0.328, O2=0.289, score=0.316
#
# Time passed at cycle 132: 10807.0s.
# === MLP Cycle 132 (t=10807.0s) ===
# [MLP] split=0.583, C=82.1, O1=0.324, O2=0.137, score=0.268
#
# Time passed at cycle 133: 10889.0s.
# === MLP Cycle 133 (t=10889.0s) ===
# [MLP] split=0.578, C=83.6, O1=0.345, O2=0.181, score=0.296
#
# Time passed at cycle 134: 10972.0s.
# === MLP Cycle 134 (t=10972.0s) ===
# [MLP] split=0.582, C=83.0, O1=0.427, O2=0.357, score=0.406
#
# Time passed at cycle 135: 11054.0s.
# === MLP Cycle 135 (t=11054.0s) ===
# [MLP] split=0.584, C=82.8, O1=0.369, O2=0.330, score=0.357
#
# Time passed at cycle 136: 11136.0s.
# === MLP Cycle 136 (t=11136.0s) ===
# [MLP] split=0.579, C=82.0, O1=0.294, O2=0.011, score=0.209
#
# Time passed at cycle 137: 11218.0s.
# === MLP Cycle 137 (t=11218.0s) ===
# [MLP] split=0.578, C=83.2, O1=0.385, O2=0.264, score=0.348
#
# Time passed at cycle 138: 11301.0s.
# === MLP Cycle 138 (t=11301.0s) ===
# [MLP] split=0.580, C=83.0, O1=0.429, O2=0.131, score=0.340
#
# Time passed at cycle 139: 11383.0s.
# === MLP Cycle 139 (t=11383.0s) ===
# [MLP] split=0.585, C=85.7, O1=0.372, O2=0.074, score=0.283
#
# Time passed at cycle 140: 11468.0s.
# === MLP Cycle 140 (t=11468.0s) ===
# [MLP] split=0.586, C=83.3, O1=0.352, O2=0.101, score=0.277
#
# Time passed at cycle 141: 11551.0s.
# === MLP Cycle 141 (t=11551.0s) ===
# [MLP] split=0.589, C=82.4, O1=0.323, O2=0.117, score=0.261
#
# Time passed at cycle 142: 11633.0s.
# === MLP Cycle 142 (t=11633.0s) ===
# [MLP] split=0.588, C=82.1, O1=0.352, O2=0.024, score=0.254
#
# Time passed at cycle 143: 11715.0s.
# === MLP Cycle 143 (t=11715.0s) ===
# [MLP] split=0.585, C=83.7, O1=0.365, O2=0.058, score=0.273
#
# Time passed at cycle 144: 11798.0s.
# === MLP Cycle 144 (t=11798.0s) ===
# [MLP] split=0.588, C=83.2, O1=0.241, O2=0.020, score=0.175
#
# Time passed at cycle 145: 11881.0s.
# === MLP Cycle 145 (t=11881.0s) ===
# [MLP] split=0.587, C=83.0, O1=0.361, O2=0.266, score=0.333
#
# Time passed at cycle 146: 11963.0s.
# === MLP Cycle 146 (t=11963.0s) ===
# [MLP] split=0.585, C=82.2, O1=0.340, O2=0.139, score=0.280
#
# Time passed at cycle 147: 12045.0s.
# === MLP Cycle 147 (t=12045.0s) ===
# [MLP] split=0.583, C=83.0, O1=0.390, O2=0.033, score=0.283
#
# Time passed at cycle 148: 12127.0s.
# === MLP Cycle 148 (t=12127.0s) ===
# [MLP] split=0.582, C=85.9, O1=0.280, O2=0.267, score=0.276
#
# Time passed at cycle 149: 12212.0s.
# === MLP Cycle 149 (t=12212.0s) ===
# [MLP] split=0.593, C=83.8, O1=0.373, O2=0.114, score=0.296
#
# Time passed at cycle 150: 12295.0s.
# === MLP Cycle 150 (t=12295.0s) ===
# [MLP] split=0.595, C=83.2, O1=0.339, O2=0.085, score=0.263
#
# Time passed at cycle 151: 12378.0s.
# === MLP Cycle 151 (t=12378.0s) ===
# [MLP] split=0.593, C=82.3, O1=0.291, O2=0.029, score=0.213
#
# Time passed at cycle 152: 12460.0s.
# === MLP Cycle 152 (t=12460.0s) ===
# [MLP] split=0.587, C=82.2, O1=0.420, O2=0.273, score=0.376
#
# Time passed at cycle 153: 12542.0s.
# === MLP Cycle 153 (t=12542.0s) ===
# [MLP] split=0.591, C=83.4, O1=0.362, O2=0.184, score=0.309
#
# Time passed at cycle 154: 12625.0s.
# === MLP Cycle 154 (t=12625.0s) ===
# [MLP] split=0.588, C=82.4, O1=0.320, O2=0.108, score=0.256
#
# Time passed at cycle 155: 12707.0s.
# === MLP Cycle 155 (t=12707.0s) ===
# [MLP] split=0.584, C=82.4, O1=0.315, O2=0.217, score=0.286
#
# Time passed at cycle 156: 12789.0s.
# === MLP Cycle 156 (t=12789.0s) ===
# [MLP] split=0.581, C=82.2, O1=0.343, O2=0.062, score=0.259
#
# Time passed at cycle 157: 12871.0s.
# === MLP Cycle 157 (t=12871.0s) ===
# [MLP] split=0.581, C=84.2, O1=0.331, O2=0.203, score=0.293
#
# Time passed at cycle 158: 12955.0s.
# === MLP Cycle 158 (t=12955.0s) ===
# [MLP] split=0.581, C=82.3, O1=0.280, O2=0.003, score=0.197
#
# Time passed at cycle 159: 13037.0s.
# === MLP Cycle 159 (t=13037.0s) ===
# [MLP] split=0.579, C=82.8, O1=0.344, O2=0.314, score=0.335
#
# Time passed at cycle 160: 13119.0s.
# === MLP Cycle 160 (t=13119.0s) ===
# [MLP] split=0.578, C=82.3, O1=0.309, O2=0.059, score=0.234
#
# Time passed at cycle 161: 13201.0s.
# === MLP Cycle 161 (t=13201.0s) ===
# [MLP] split=0.579, C=83.5, O1=0.434, O2=0.243, score=0.377
#
# Time passed at cycle 162: 13284.0s.
# === MLP Cycle 162 (t=13284.0s) ===
# [MLP] split=0.586, C=84.4, O1=0.321, O2=0.060, score=0.243
#
# Time passed at cycle 163: 13368.0s.
# === MLP Cycle 163 (t=13368.0s) ===
# [MLP] split=0.582, C=82.8, O1=0.270, O2=0.001, score=0.190
#
# Time passed at cycle 164: 13450.0s.
# === MLP Cycle 164 (t=13450.0s) ===
# [MLP] split=0.582, C=82.7, O1=0.362, O2=0.296, score=0.343
#
# Time passed at cycle 165: 13532.0s.
# === MLP Cycle 165 (t=13532.0s) ===
# [MLP] split=0.581, C=82.5, O1=0.361, O2=0.137, score=0.294
#
# Time passed at cycle 166: 13614.0s.
# === MLP Cycle 166 (t=13614.0s) ===
# [MLP] split=0.569, C=84.6, O1=0.339, O2=0.076, score=0.260
#
# Time passed at cycle 167: 13698.0s.
# === MLP Cycle 167 (t=13698.0s) ===
# [MLP] split=0.577, C=83.9, O1=0.275, O2=0.061, score=0.210
#
# Time passed at cycle 168: 13781.0s.
# === MLP Cycle 168 (t=13781.0s) ===
# [MLP] split=0.583, C=82.8, O1=0.249, O2=0.003, score=0.175
#
# Time passed at cycle 169: 13863.0s.
# === MLP Cycle 169 (t=13863.0s) ===
# [MLP] split=0.584, C=83.2, O1=0.331, O2=0.213, score=0.296
#
# Time passed at cycle 170: 13946.0s.
# === MLP Cycle 170 (t=13946.0s) ===
# [MLP] split=0.583, C=83.6, O1=0.325, O2=0.096, score=0.256
#
# Time passed at cycle 171: 14029.0s.
# === MLP Cycle 171 (t=14029.0s) ===
# [MLP] split=0.579, C=83.8, O1=0.293, O2=0.051, score=0.220
#
# Time passed at cycle 172: 14112.0s.
# === MLP Cycle 172 (t=14112.0s) ===
# [MLP] split=0.584, C=83.3, O1=0.360, O2=0.109, score=0.285
#
# Time passed at cycle 173: 14195.0s.
# === MLP Cycle 173 (t=14195.0s) ===
# [MLP] split=0.576, C=84.4, O1=0.277, O2=0.103, score=0.225
#
# Time passed at cycle 174: 14279.0s.
# === MLP Cycle 174 (t=14279.0s) ===
# [MLP] split=0.588, C=83.0, O1=0.268, O2=0.080, score=0.212
#
# Time passed at cycle 175: 14362.0s.
# === MLP Cycle 175 (t=14362.0s) ===
# [MLP] split=0.587, C=82.9, O1=0.293, O2=0.063, score=0.224
#
# Time passed at cycle 176: 14444.0s.
# === MLP Cycle 176 (t=14444.0s) ===
# [MLP] split=0.584, C=83.2, O1=0.252, O2=0.015, score=0.181
#
# Time passed at cycle 177: 14527.0s.
# === MLP Cycle 177 (t=14527.0s) ===
# [MLP] split=0.585, C=83.4, O1=0.250, O2=0.049, score=0.190
#
# Time passed at cycle 178: 14610.0s.
# === MLP Cycle 178 (t=14610.0s) ===
# [MLP] split=0.584, C=83.5, O1=0.319, O2=0.162, score=0.272
#
# Time passed at cycle 179: 14693.0s.
# === MLP Cycle 179 (t=14693.0s) ===
# [MLP] split=0.581, C=84.3, O1=0.228, O2=0.013, score=0.163
#
# Time passed at cycle 180: 14777.0s.
# === MLP Cycle 180 (t=14777.0s) ===
# [MLP] split=0.594, C=84.5, O1=0.248, O2=0.054, score=0.190
#
# Time passed at cycle 181: 14861.0s.
# === MLP Cycle 181 (t=14861.0s) ===
# [MLP] split=0.592, C=84.0, O1=0.301, O2=0.019, score=0.216
#
# Time passed at cycle 182: 14944.0s.
# === MLP Cycle 182 (t=14944.0s) ===
# [MLP] split=0.585, C=83.6, O1=0.268, O2=0.117, score=0.223
#
# Time passed at cycle 183: 15027.0s.
# === MLP Cycle 183 (t=15027.0s) ===
# [MLP] split=0.583, C=83.3, O1=0.298, O2=0.122, score=0.245
#
# Time passed at cycle 184: 15110.0s.
# === MLP Cycle 184 (t=15110.0s) ===
# [MLP] split=0.579, C=83.1, O1=0.345, O2=0.082, score=0.266
#
# Time passed at cycle 185: 15193.0s.
# === MLP Cycle 185 (t=15193.0s) ===
# [MLP] split=0.567, C=85.8, O1=0.258, O2=0.006, score=0.183
#
# Time passed at cycle 186: 15278.0s.
# === MLP Cycle 186 (t=15278.0s) ===
# [MLP] split=0.580, C=83.6, O1=0.312, O2=0.119, score=0.254
#
# Time passed at cycle 187: 15361.0s.
# === MLP Cycle 187 (t=15361.0s) ===
# [MLP] split=0.581, C=82.9, O1=0.272, O2=0.016, score=0.195
#
# Time passed at cycle 188: 15443.0s.
# === MLP Cycle 188 (t=15443.0s) ===
# [MLP] split=0.581, C=83.1, O1=0.284, O2=0.032, score=0.208
#
# Time passed at cycle 189: 15526.0s.
# === MLP Cycle 189 (t=15526.0s) ===
# [MLP] split=0.580, C=83.3, O1=0.302, O2=0.144, score=0.255
#
# Time passed at cycle 190: 15609.0s.
# === MLP Cycle 190 (t=15609.0s) ===
# [MLP] split=0.583, C=83.7, O1=0.278, O2=0.080, score=0.219
#
# Time passed at cycle 191: 15692.0s.
# === MLP Cycle 191 (t=15692.0s) ===
# [MLP] split=0.588, C=83.5, O1=0.338, O2=0.321, score=0.333
#
# Time passed at cycle 192: 15775.0s.
# === MLP Cycle 192 (t=15775.0s) ===
# [MLP] split=0.582, C=82.5, O1=0.340, O2=0.097, score=0.268
#
# Time passed at cycle 193: 15857.0s.
# === MLP Cycle 193 (t=15857.0s) ===
# [MLP] split=0.584, C=84.1, O1=0.335, O2=0.131, score=0.274
#
# Time passed at cycle 194: 15941.0s.
# === MLP Cycle 194 (t=15941.0s) ===
# [MLP] split=0.575, C=84.0, O1=0.240, O2=0.059, score=0.186
#
# Time passed at cycle 195: 16024.0s.
# === MLP Cycle 195 (t=16024.0s) ===
# [MLP] split=0.589, C=84.0, O1=0.215, O2=0.149, score=0.196
#
# Time passed at cycle 196: 16107.0s.
# === MLP Cycle 196 (t=16107.0s) ===
# [MLP] split=0.595, C=84.8, O1=0.256, O2=0.078, score=0.203
#
# Time passed at cycle 197: 16191.0s.
# === MLP Cycle 197 (t=16191.0s) ===
# [MLP] split=0.580, C=83.3, O1=0.242, O2=0.007, score=0.172
#
# Time passed at cycle 198: 16274.0s.
# Elapsed time exceed at: cycle 198, stopping early.
#
# ✅ MLP simulation completed — results saved to logs/traffic_MLP_summary_20251209_101741.csv

# %%
from src import config
from src.utils import visualize_pow_results

visualize_pow_results(log_dir=config.LOG_DIR, suffix="20251209_101741", prefix="traffic_MLP")
# Out:
# Loaded 197 cycles from logs/traffic_MLP_summary_20251209_101741.csv
# === Summary statistics ===
#              s        C       O1       O2  score_best  elapsed_s
# count  197.000  197.000  197.000  197.000     197.000      197.0
# mean     0.587   83.115    0.276    0.161       0.241        0.0
# std      0.023    1.916    0.106    0.131       0.080        0.0
# min      0.546   76.900    0.049    0.001       0.071        0.0
# 25%      0.575   82.300    0.178    0.068       0.186        0.0
# 50%      0.583   83.100    0.298    0.129       0.245        0.0
# 75%      0.595   83.900    0.352    0.236       0.294        0.0
# max      0.664   88.500    0.540    0.916       0.468        0.0
#
# ✅  Average runtime per DE optimization: 0.00s
# ✅ Visualization complete — core PoW evidence generated.

# %%
from src.de_experiment import baseline_simulation

baseline_simulation()
# Out:
# Running baseline simulation: s=0.5, C=90s for 300 cycles
#
# Time passed at cycle 1: 1.0s.
# === Cycle 1 (t=1.0s) ===
# Vehicles currently in simulation: 1
# Fixed split=0.50, C=90.0, O1=0.088, O2=0.433, score=0.192
#
# Time passed at cycle 2: 91.0s.
# === Cycle 2 (t=91.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.129, O2=0.930, score=0.369
#
# Time passed at cycle 3: 181.0s.
# === Cycle 3 (t=181.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.162, O2=0.508, score=0.266
#
# Time passed at cycle 4: 271.0s.
# === Cycle 4 (t=271.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.124, O2=0.329, score=0.186
#
# Time passed at cycle 5: 361.0s.
# === Cycle 5 (t=361.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.118, O2=0.048, score=0.097
#
# Time passed at cycle 6: 451.0s.
# === Cycle 6 (t=451.0s) ===
# Vehicles currently in simulation: 23
# Fixed split=0.50, C=90.0, O1=0.144, O2=0.096, score=0.130
#
# Time passed at cycle 7: 541.0s.
# === Cycle 7 (t=541.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.094, O2=0.221, score=0.132
#
# Time passed at cycle 8: 631.0s.
# === Cycle 8 (t=631.0s) ===
# Vehicles currently in simulation: 17
# Fixed split=0.50, C=90.0, O1=0.198, O2=0.400, score=0.259
#
# Time passed at cycle 9: 721.0s.
# === Cycle 9 (t=721.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.112, O2=0.323, score=0.175
#
# Time passed at cycle 10: 811.0s.
# === Cycle 10 (t=811.0s) ===
# Vehicles currently in simulation: 21
# Fixed split=0.50, C=90.0, O1=0.129, O2=0.428, score=0.219
#
# Time passed at cycle 11: 901.0s.
# === Cycle 11 (t=901.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.129, O2=0.262, score=0.169
#
# Time passed at cycle 12: 991.0s.
# === Cycle 12 (t=991.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.095, O2=0.018, score=0.072
#
# Time passed at cycle 13: 1081.0s.
# === Cycle 13 (t=1081.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.129, O2=0.205, score=0.152
#
# Time passed at cycle 14: 1171.0s.
# === Cycle 14 (t=1171.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.153, O2=0.408, score=0.229
#
# Time passed at cycle 15: 1261.0s.
# === Cycle 15 (t=1261.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.109, O2=0.034, score=0.087
#
# Time passed at cycle 16: 1351.0s.
# === Cycle 16 (t=1351.0s) ===
# Vehicles currently in simulation: 20
# Fixed split=0.50, C=90.0, O1=0.075, O2=0.070, score=0.074
#
# Time passed at cycle 17: 1441.0s.
# === Cycle 17 (t=1441.0s) ===
# Vehicles currently in simulation: 19
# Fixed split=0.50, C=90.0, O1=0.135, O2=0.242, score=0.167
#
# Time passed at cycle 18: 1531.0s.
# === Cycle 18 (t=1531.0s) ===
# Vehicles currently in simulation: 26
# Fixed split=0.50, C=90.0, O1=0.148, O2=0.279, score=0.187
#
# Time passed at cycle 19: 1621.0s.
# === Cycle 19 (t=1621.0s) ===
# Vehicles currently in simulation: 26
# Fixed split=0.50, C=90.0, O1=0.135, O2=0.404, score=0.216
#
# Time passed at cycle 20: 1711.0s.
# === Cycle 20 (t=1711.0s) ===
# Vehicles currently in simulation: 26
# Fixed split=0.50, C=90.0, O1=0.165, O2=0.683, score=0.321
#
# Time passed at cycle 21: 1801.0s.
# === Cycle 21 (t=1801.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.158, O2=0.074, score=0.133
#
# Time passed at cycle 22: 1891.0s.
# === Cycle 22 (t=1891.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.127, O2=0.823, score=0.336
#
# Time passed at cycle 23: 1981.0s.
# === Cycle 23 (t=1981.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.178, O2=0.355, score=0.231
#
# Time passed at cycle 24: 2071.0s.
# === Cycle 24 (t=2071.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.134, O2=0.000, score=0.094
#
# Time passed at cycle 25: 2161.0s.
# === Cycle 25 (t=2161.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.132, O2=0.082, score=0.117
#
# Time passed at cycle 26: 2251.0s.
# === Cycle 26 (t=2251.0s) ===
# Vehicles currently in simulation: 32
# Fixed split=0.50, C=90.0, O1=0.131, O2=0.053, score=0.108
#
# Time passed at cycle 27: 2341.0s.
# === Cycle 27 (t=2341.0s) ===
# Vehicles currently in simulation: 24
# Fixed split=0.50, C=90.0, O1=0.210, O2=0.274, score=0.229
#
# Time passed at cycle 28: 2431.0s.
# === Cycle 28 (t=2431.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.103, O2=0.114, score=0.106
#
# Time passed at cycle 29: 2521.0s.
# === Cycle 29 (t=2521.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.174, O2=0.418, score=0.247
#
# Time passed at cycle 30: 2611.0s.
# === Cycle 30 (t=2611.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.153, O2=0.278, score=0.191
#
# Time passed at cycle 31: 2701.0s.
# === Cycle 31 (t=2701.0s) ===
# Vehicles currently in simulation: 24
# Fixed split=0.50, C=90.0, O1=0.113, O2=0.150, score=0.124
#
# Time passed at cycle 32: 2791.0s.
# === Cycle 32 (t=2791.0s) ===
# Vehicles currently in simulation: 27
# Fixed split=0.50, C=90.0, O1=0.165, O2=0.397, score=0.235
#
# Time passed at cycle 33: 2881.0s.
# === Cycle 33 (t=2881.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.135, O2=0.499, score=0.244
#
# Time passed at cycle 34: 2971.0s.
# === Cycle 34 (t=2971.0s) ===
# Vehicles currently in simulation: 25
# Fixed split=0.50, C=90.0, O1=0.177, O2=0.386, score=0.240
#
# Time passed at cycle 35: 3061.0s.
# === Cycle 35 (t=3061.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.190, O2=0.268, score=0.213
#
# Time passed at cycle 36: 3151.0s.
# === Cycle 36 (t=3151.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.197, O2=0.574, score=0.310
#
# Time passed at cycle 37: 3241.0s.
# === Cycle 37 (t=3241.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.190, O2=0.537, score=0.294
#
# Time passed at cycle 38: 3331.0s.
# === Cycle 38 (t=3331.0s) ===
# Vehicles currently in simulation: 29
# Fixed split=0.50, C=90.0, O1=0.164, O2=0.437, score=0.246
#
# Time passed at cycle 39: 3421.0s.
# === Cycle 39 (t=3421.0s) ===
# Vehicles currently in simulation: 28
# Fixed split=0.50, C=90.0, O1=0.137, O2=0.368, score=0.206
#
# Time passed at cycle 40: 3511.0s.
# === Cycle 40 (t=3511.0s) ===
# Vehicles currently in simulation: 22
# Fixed split=0.50, C=90.0, O1=0.186, O2=0.213, score=0.194
#
# Time passed at cycle 41: 3601.0s.
# === Cycle 41 (t=3601.0s) ===
# Vehicles currently in simulation: 26
# Fixed split=0.50, C=90.0, O1=0.171, O2=0.102, score=0.150
#
# Time passed at cycle 42: 3691.0s.
# === Cycle 42 (t=3691.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.259, O2=0.651, score=0.377
#
# Time passed at cycle 43: 3781.0s.
# === Cycle 43 (t=3781.0s) ===
# Vehicles currently in simulation: 40
# Fixed split=0.50, C=90.0, O1=0.254, O2=0.217, score=0.243
#
# Time passed at cycle 44: 3871.0s.
# === Cycle 44 (t=3871.0s) ===
# Vehicles currently in simulation: 38
# Fixed split=0.50, C=90.0, O1=0.196, O2=0.203, score=0.198
#
# Time passed at cycle 45: 3961.0s.
# === Cycle 45 (t=3961.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.170, O2=0.014, score=0.123
#
# Time passed at cycle 46: 4051.0s.
# === Cycle 46 (t=4051.0s) ===
# Vehicles currently in simulation: 32
# Fixed split=0.50, C=90.0, O1=0.259, O2=0.038, score=0.193
#
# Time passed at cycle 47: 4141.0s.
# === Cycle 47 (t=4141.0s) ===
# Vehicles currently in simulation: 43
# Fixed split=0.50, C=90.0, O1=0.197, O2=0.470, score=0.279
#
# Time passed at cycle 48: 4231.0s.
# === Cycle 48 (t=4231.0s) ===
# Vehicles currently in simulation: 33
# Fixed split=0.50, C=90.0, O1=0.128, O2=0.135, score=0.130
#
# Time passed at cycle 49: 4321.0s.
# === Cycle 49 (t=4321.0s) ===
# Vehicles currently in simulation: 31
# Fixed split=0.50, C=90.0, O1=0.294, O2=0.481, score=0.350
#
# Time passed at cycle 50: 4411.0s.
# === Cycle 50 (t=4411.0s) ===
# Vehicles currently in simulation: 42
# Fixed split=0.50, C=90.0, O1=0.364, O2=0.679, score=0.458
#
# Time passed at cycle 51: 4501.0s.
# === Cycle 51 (t=4501.0s) ===
# Vehicles currently in simulation: 44
# Fixed split=0.50, C=90.0, O1=0.336, O2=0.472, score=0.377
#
# Time passed at cycle 52: 4591.0s.
# === Cycle 52 (t=4591.0s) ===
# Vehicles currently in simulation: 41
# Fixed split=0.50, C=90.0, O1=0.165, O2=0.066, score=0.135
#
# Time passed at cycle 53: 4681.0s.
# === Cycle 53 (t=4681.0s) ===
# Vehicles currently in simulation: 30
# Fixed split=0.50, C=90.0, O1=0.185, O2=0.203, score=0.190
#
# Time passed at cycle 54: 4771.0s.
# === Cycle 54 (t=4771.0s) ===
# Vehicles currently in simulation: 38
# Fixed split=0.50, C=90.0, O1=0.372, O2=0.622, score=0.447
#
# Time passed at cycle 55: 4861.0s.
# === Cycle 55 (t=4861.0s) ===
# Vehicles currently in simulation: 43
# Fixed split=0.50, C=90.0, O1=0.312, O2=0.457, score=0.356
#
# Time passed at cycle 56: 4951.0s.
# === Cycle 56 (t=4951.0s) ===
# Vehicles currently in simulation: 44
# Fixed split=0.50, C=90.0, O1=0.186, O2=0.115, score=0.165
#
# Time passed at cycle 57: 5041.0s.
# === Cycle 57 (t=5041.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.183, O2=0.045, score=0.142
#
# Time passed at cycle 58: 5131.0s.
# === Cycle 58 (t=5131.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.215, O2=0.105, score=0.182
#
# Time passed at cycle 59: 5221.0s.
# === Cycle 59 (t=5221.0s) ===
# Vehicles currently in simulation: 34
# Fixed split=0.50, C=90.0, O1=0.226, O2=0.265, score=0.237
#
# Time passed at cycle 60: 5311.0s.
# === Cycle 60 (t=5311.0s) ===
# Vehicles currently in simulation: 35
# Fixed split=0.50, C=90.0, O1=0.315, O2=0.357, score=0.328
#
# Time passed at cycle 61: 5401.0s.
# === Cycle 61 (t=5401.0s) ===
# Vehicles currently in simulation: 42
# Fixed split=0.50, C=90.0, O1=0.359, O2=0.348, score=0.356
#
# Time passed at cycle 62: 5491.0s.
# === Cycle 62 (t=5491.0s) ===
# Vehicles currently in simulation: 62
# Fixed split=0.50, C=90.0, O1=0.485, O2=0.401, score=0.459
#
# Time passed at cycle 63: 5581.0s.
# === Cycle 63 (t=5581.0s) ===
# Vehicles currently in simulation: 70
# Fixed split=0.50, C=90.0, O1=0.350, O2=0.199, score=0.305
#
# Time passed at cycle 64: 5671.0s.
# === Cycle 64 (t=5671.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.326, O2=0.079, score=0.252
#
# Time passed at cycle 65: 5761.0s.
# === Cycle 65 (t=5761.0s) ===
# Vehicles currently in simulation: 66
# Fixed split=0.50, C=90.0, O1=0.432, O2=0.326, score=0.401
#
# Time passed at cycle 66: 5851.0s.
# === Cycle 66 (t=5851.0s) ===
# Vehicles currently in simulation: 80
# Fixed split=0.50, C=90.0, O1=0.343, O2=0.156, score=0.287
#
# Time passed at cycle 67: 5941.0s.
# === Cycle 67 (t=5941.0s) ===
# Vehicles currently in simulation: 79
# Fixed split=0.50, C=90.0, O1=0.339, O2=0.345, score=0.341
#
# Time passed at cycle 68: 6031.0s.
# === Cycle 68 (t=6031.0s) ===
# Vehicles currently in simulation: 80
# Fixed split=0.50, C=90.0, O1=0.413, O2=0.431, score=0.418
#
# Time passed at cycle 69: 6121.0s.
# === Cycle 69 (t=6121.0s) ===
# Vehicles currently in simulation: 88
# Fixed split=0.50, C=90.0, O1=0.306, O2=0.262, score=0.293
#
# Time passed at cycle 70: 6211.0s.
# === Cycle 70 (t=6211.0s) ===
# Vehicles currently in simulation: 94
# Fixed split=0.50, C=90.0, O1=0.294, O2=0.215, score=0.271
#
# Time passed at cycle 71: 6301.0s.
# === Cycle 71 (t=6301.0s) ===
# Vehicles currently in simulation: 93
# Fixed split=0.50, C=90.0, O1=0.300, O2=0.209, score=0.273
#
# Time passed at cycle 72: 6391.0s.
# === Cycle 72 (t=6391.0s) ===
# Vehicles currently in simulation: 95
# Fixed split=0.50, C=90.0, O1=0.418, O2=0.433, score=0.422
#
# Time passed at cycle 73: 6481.0s.
# === Cycle 73 (t=6481.0s) ===
# Vehicles currently in simulation: 89
# Fixed split=0.50, C=90.0, O1=0.388, O2=0.262, score=0.350
#
# Time passed at cycle 74: 6571.0s.
# === Cycle 74 (t=6571.0s) ===
# Vehicles currently in simulation: 91
# Fixed split=0.50, C=90.0, O1=0.451, O2=0.505, score=0.468
#
# Time passed at cycle 75: 6661.0s.
# === Cycle 75 (t=6661.0s) ===
# Vehicles currently in simulation: 89
# Fixed split=0.50, C=90.0, O1=0.395, O2=0.394, score=0.395
#
# Time passed at cycle 76: 6751.0s.
# === Cycle 76 (t=6751.0s) ===
# Vehicles currently in simulation: 85
# Fixed split=0.50, C=90.0, O1=0.346, O2=0.090, score=0.269
#
# Time passed at cycle 77: 6841.0s.
# === Cycle 77 (t=6841.0s) ===
# Vehicles currently in simulation: 81
# Fixed split=0.50, C=90.0, O1=0.328, O2=0.099, score=0.259
#
# Time passed at cycle 78: 6931.0s.
# === Cycle 78 (t=6931.0s) ===
# Vehicles currently in simulation: 79
# Fixed split=0.50, C=90.0, O1=0.548, O2=0.389, score=0.501
#
# Time passed at cycle 79: 7021.0s.
# === Cycle 79 (t=7021.0s) ===
# Vehicles currently in simulation: 91
# Fixed split=0.50, C=90.0, O1=0.414, O2=0.202, score=0.350
#
# Time passed at cycle 80: 7111.0s.
# === Cycle 80 (t=7111.0s) ===
# Vehicles currently in simulation: 95
# Fixed split=0.50, C=90.0, O1=0.315, O2=0.108, score=0.252
#
# Time passed at cycle 81: 7201.0s.
# === Cycle 81 (t=7201.0s) ===
# Vehicles currently in simulation: 84
# Fixed split=0.50, C=90.0, O1=0.491, O2=0.263, score=0.423
#
# Time passed at cycle 82: 7291.0s.
# === Cycle 82 (t=7291.0s) ===
# Vehicles currently in simulation: 138
# Fixed split=0.50, C=90.0, O1=0.561, O2=0.290, score=0.480
#
# Time passed at cycle 83: 7381.0s.
# === Cycle 83 (t=7381.0s) ===
# Vehicles currently in simulation: 162
# Fixed split=0.50, C=90.0, O1=0.503, O2=0.169, score=0.402
#
# Time passed at cycle 84: 7471.0s.
# === Cycle 84 (t=7471.0s) ===
# Vehicles currently in simulation: 185
# Fixed split=0.50, C=90.0, O1=0.457, O2=0.192, score=0.378
#
# Time passed at cycle 85: 7561.0s.
# === Cycle 85 (t=7561.0s) ===
# Vehicles currently in simulation: 185
# Fixed split=0.50, C=90.0, O1=0.704, O2=0.385, score=0.609
#
# Time passed at cycle 86: 7651.0s.
# === Cycle 86 (t=7651.0s) ===
# Vehicles currently in simulation: 179
# Fixed split=0.50, C=90.0, O1=0.661, O2=0.318, score=0.558
#
# Time passed at cycle 87: 7741.0s.
# === Cycle 87 (t=7741.0s) ===
# Vehicles currently in simulation: 191
# Fixed split=0.50, C=90.0, O1=0.688, O2=0.412, score=0.605
#
# Time passed at cycle 88: 7831.0s.
# === Cycle 88 (t=7831.0s) ===
# Vehicles currently in simulation: 199
# Fixed split=0.50, C=90.0, O1=0.755, O2=0.368, score=0.639
#
# Time passed at cycle 89: 7921.0s.
# === Cycle 89 (t=7921.0s) ===
# Vehicles currently in simulation: 197
# Fixed split=0.50, C=90.0, O1=0.724, O2=0.474, score=0.649
#
# Time passed at cycle 90: 8011.0s.
# === Cycle 90 (t=8011.0s) ===
# Vehicles currently in simulation: 210
# Fixed split=0.50, C=90.0, O1=0.687, O2=0.523, score=0.638
#
# Time passed at cycle 91: 8101.0s.
# === Cycle 91 (t=8101.0s) ===
# Vehicles currently in simulation: 234
# Fixed split=0.50, C=90.0, O1=0.988, O2=0.685, score=0.897
#
# Time passed at cycle 92: 8191.0s.
# === Cycle 92 (t=8191.0s) ===
# Vehicles currently in simulation: 258
# Fixed split=0.50, C=90.0, O1=0.844, O2=0.560, score=0.758
#
# Time passed at cycle 93: 8281.0s.
# === Cycle 93 (t=8281.0s) ===
# Vehicles currently in simulation: 248
# Fixed split=0.50, C=90.0, O1=0.712, O2=0.568, score=0.669
#
# Time passed at cycle 94: 8371.0s.
# === Cycle 94 (t=8371.0s) ===
# Vehicles currently in simulation: 247
# Fixed split=0.50, C=90.0, O1=0.495, O2=0.426, score=0.474
#
# Time passed at cycle 95: 8461.0s.
# === Cycle 95 (t=8461.0s) ===
# Vehicles currently in simulation: 229
# Fixed split=0.50, C=90.0, O1=0.846, O2=0.571, score=0.763
#
# Time passed at cycle 96: 8551.0s.
# === Cycle 96 (t=8551.0s) ===
# Vehicles currently in simulation: 239
# Fixed split=0.50, C=90.0, O1=0.753, O2=0.733, score=0.747
#
# Time passed at cycle 97: 8641.0s.
# === Cycle 97 (t=8641.0s) ===
# Vehicles currently in simulation: 247
# Fixed split=0.50, C=90.0, O1=0.775, O2=0.577, score=0.716
#
# Time passed at cycle 98: 8731.0s.
# === Cycle 98 (t=8731.0s) ===
# Vehicles currently in simulation: 252
# Fixed split=0.50, C=90.0, O1=0.668, O2=0.630, score=0.657
#
# Time passed at cycle 99: 8821.0s.
# === Cycle 99 (t=8821.0s) ===
# Vehicles currently in simulation: 245
# Fixed split=0.50, C=90.0, O1=0.819, O2=0.581, score=0.748
#
# Time passed at cycle 100: 8911.0s.
# === Cycle 100 (t=8911.0s) ===
# Vehicles currently in simulation: 250
# Fixed split=0.50, C=90.0, O1=0.707, O2=0.695, score=0.703
#
# Time passed at cycle 101: 9001.0s.
# === Cycle 101 (t=9001.0s) ===
# Vehicles currently in simulation: 247
# Fixed split=0.50, C=90.0, O1=0.756, O2=0.283, score=0.614
#
# Time passed at cycle 102: 9091.0s.
# === Cycle 102 (t=9091.0s) ===
# Vehicles currently in simulation: 252
# Fixed split=0.50, C=90.0, O1=0.888, O2=0.534, score=0.782
#
# Time passed at cycle 103: 9181.0s.
# === Cycle 103 (t=9181.0s) ===
# Vehicles currently in simulation: 231
# Fixed split=0.50, C=90.0, O1=1.000, O2=0.607, score=0.882
#
# Time passed at cycle 104: 9271.0s.
# === Cycle 104 (t=9271.0s) ===
# Vehicles currently in simulation: 231
# Fixed split=0.50, C=90.0, O1=0.750, O2=0.535, score=0.686
#
# Time passed at cycle 105: 9361.0s.
# === Cycle 105 (t=9361.0s) ===
# Vehicles currently in simulation: 199
# Fixed split=0.50, C=90.0, O1=0.600, O2=0.521, score=0.576
#
# Time passed at cycle 106: 9451.0s.
# === Cycle 106 (t=9451.0s) ===
# Vehicles currently in simulation: 191
# Fixed split=0.50, C=90.0, O1=0.544, O2=0.469, score=0.522
#
# Time passed at cycle 107: 9541.0s.
# === Cycle 107 (t=9541.0s) ===
# Vehicles currently in simulation: 187
# Fixed split=0.50, C=90.0, O1=0.794, O2=0.698, score=0.765
#
# Time passed at cycle 108: 9631.0s.
# === Cycle 108 (t=9631.0s) ===
# Vehicles currently in simulation: 205
# Fixed split=0.50, C=90.0, O1=0.550, O2=0.358, score=0.493
#
# Time passed at cycle 109: 9721.0s.
# === Cycle 109 (t=9721.0s) ===
# Vehicles currently in simulation: 179
# Fixed split=0.50, C=90.0, O1=0.542, O2=0.397, score=0.499
#
# Time passed at cycle 110: 9811.0s.
# === Cycle 110 (t=9811.0s) ===
# Vehicles currently in simulation: 183
# Fixed split=0.50, C=90.0, O1=0.510, O2=0.324, score=0.455
#
# Time passed at cycle 111: 9901.0s.
# === Cycle 111 (t=9901.0s) ===
# Vehicles currently in simulation: 163
# Fixed split=0.50, C=90.0, O1=0.521, O2=0.349, score=0.469
#
# Time passed at cycle 112: 9991.0s.
# === Cycle 112 (t=9991.0s) ===
# Vehicles currently in simulation: 179
# Fixed split=0.50, C=90.0, O1=0.466, O2=0.256, score=0.403
#
# Time passed at cycle 113: 10081.0s.
# === Cycle 113 (t=10081.0s) ===
# Vehicles currently in simulation: 169
# Fixed split=0.50, C=90.0, O1=0.363, O2=0.311, score=0.347
#
# Time passed at cycle 114: 10171.0s.
# === Cycle 114 (t=10171.0s) ===
# Vehicles currently in simulation: 158
# Fixed split=0.50, C=90.0, O1=0.441, O2=0.332, score=0.408
#
# Time passed at cycle 115: 10261.0s.
# === Cycle 115 (t=10261.0s) ===
# Vehicles currently in simulation: 170
# Fixed split=0.50, C=90.0, O1=0.529, O2=0.395, score=0.488
#
# Time passed at cycle 116: 10351.0s.
# === Cycle 116 (t=10351.0s) ===
# Vehicles currently in simulation: 172
# Fixed split=0.50, C=90.0, O1=0.402, O2=0.257, score=0.358
#
# Time passed at cycle 117: 10441.0s.
# === Cycle 117 (t=10441.0s) ===
# Vehicles currently in simulation: 163
# Fixed split=0.50, C=90.0, O1=0.517, O2=0.230, score=0.431
#
# Time passed at cycle 118: 10531.0s.
# === Cycle 118 (t=10531.0s) ===
# Vehicles currently in simulation: 137
# Fixed split=0.50, C=90.0, O1=0.519, O2=0.351, score=0.469
#
# Time passed at cycle 119: 10621.0s.
# === Cycle 119 (t=10621.0s) ===
# Vehicles currently in simulation: 155
# Fixed split=0.50, C=90.0, O1=0.574, O2=0.319, score=0.497
#
# Time passed at cycle 120: 10711.0s.
# === Cycle 120 (t=10711.0s) ===
# Vehicles currently in simulation: 170
# Fixed split=0.50, C=90.0, O1=0.406, O2=0.228, score=0.353
#
# Time passed at cycle 121: 10801.0s.
# === Cycle 121 (t=10801.0s) ===
# Vehicles currently in simulation: 141
# Fixed split=0.50, C=90.0, O1=0.431, O2=0.174, score=0.354
#
# Time passed at cycle 122: 10891.0s.
# === Cycle 122 (t=10891.0s) ===
# Vehicles currently in simulation: 128
# Fixed split=0.50, C=90.0, O1=0.374, O2=0.116, score=0.296
#
# Time passed at cycle 123: 10981.0s.
# === Cycle 123 (t=10981.0s) ===
# Vehicles currently in simulation: 139
# Fixed split=0.50, C=90.0, O1=0.338, O2=0.103, score=0.267
#
# Time passed at cycle 124: 11071.0s.
# === Cycle 124 (t=11071.0s) ===
# Vehicles currently in simulation: 137
# Fixed split=0.50, C=90.0, O1=0.435, O2=0.244, score=0.378
#
# Time passed at cycle 125: 11161.0s.
# === Cycle 125 (t=11161.0s) ===
# Vehicles currently in simulation: 138
# Fixed split=0.50, C=90.0, O1=0.304, O2=0.004, score=0.214
#
# Time passed at cycle 126: 11251.0s.
# === Cycle 126 (t=11251.0s) ===
# Vehicles currently in simulation: 129
# Fixed split=0.50, C=90.0, O1=0.402, O2=0.182, score=0.336
#
# Time passed at cycle 127: 11341.0s.
# === Cycle 127 (t=11341.0s) ===
# Vehicles currently in simulation: 123
# Fixed split=0.50, C=90.0, O1=0.407, O2=0.109, score=0.317
#
# Time passed at cycle 128: 11431.0s.
# === Cycle 128 (t=11431.0s) ===
# Vehicles currently in simulation: 138
# Fixed split=0.50, C=90.0, O1=0.335, O2=0.004, score=0.235
#
# Time passed at cycle 129: 11521.0s.
# === Cycle 129 (t=11521.0s) ===
# Vehicles currently in simulation: 126
# Fixed split=0.50, C=90.0, O1=0.411, O2=0.086, score=0.314
#
# Time passed at cycle 130: 11611.0s.
# === Cycle 130 (t=11611.0s) ===
# Vehicles currently in simulation: 133
# Fixed split=0.50, C=90.0, O1=0.464, O2=0.291, score=0.412
#
# Time passed at cycle 131: 11701.0s.
# === Cycle 131 (t=11701.0s) ===
# Vehicles currently in simulation: 123
# Fixed split=0.50, C=90.0, O1=0.294, O2=0.028, score=0.214
#
# Time passed at cycle 132: 11791.0s.
# === Cycle 132 (t=11791.0s) ===
# Vehicles currently in simulation: 117
# Fixed split=0.50, C=90.0, O1=0.274, O2=0.292, score=0.279
#
# Time passed at cycle 133: 11881.0s.
# === Cycle 133 (t=11881.0s) ===
# Vehicles currently in simulation: 108
# Fixed split=0.50, C=90.0, O1=0.365, O2=0.119, score=0.292
#
# Time passed at cycle 134: 11971.0s.
# === Cycle 134 (t=11971.0s) ===
# Vehicles currently in simulation: 111
# Fixed split=0.50, C=90.0, O1=0.348, O2=0.136, score=0.284
#
# Time passed at cycle 135: 12061.0s.
# === Cycle 135 (t=12061.0s) ===
# Vehicles currently in simulation: 123
# Fixed split=0.50, C=90.0, O1=0.272, O2=0.019, score=0.196
#
# Time passed at cycle 136: 12151.0s.
# === Cycle 136 (t=12151.0s) ===
# Vehicles currently in simulation: 127
# Fixed split=0.50, C=90.0, O1=0.316, O2=0.007, score=0.223
#
# Time passed at cycle 137: 12241.0s.
# === Cycle 137 (t=12241.0s) ===
# Vehicles currently in simulation: 116
# Fixed split=0.50, C=90.0, O1=0.429, O2=0.199, score=0.360
#
# Time passed at cycle 138: 12331.0s.
# === Cycle 138 (t=12331.0s) ===
# Vehicles currently in simulation: 117
# Fixed split=0.50, C=90.0, O1=0.375, O2=0.093, score=0.290
#
# Time passed at cycle 139: 12421.0s.
# === Cycle 139 (t=12421.0s) ===
# Vehicles currently in simulation: 125
# Fixed split=0.50, C=90.0, O1=0.279, O2=0.123, score=0.232
#
# Time passed at cycle 140: 12511.0s.
# === Cycle 140 (t=12511.0s) ===
# Vehicles currently in simulation: 128
# Fixed split=0.50, C=90.0, O1=0.277, O2=0.051, score=0.209
#
# Time passed at cycle 141: 12601.0s.
# === Cycle 141 (t=12601.0s) ===
# Vehicles currently in simulation: 120
# Fixed split=0.50, C=90.0, O1=0.250, O2=0.085, score=0.201
#
# Time passed at cycle 142: 12691.0s.
# === Cycle 142 (t=12691.0s) ===
# Vehicles currently in simulation: 123
# Fixed split=0.50, C=90.0, O1=0.224, O2=0.210, score=0.220
#
# Time passed at cycle 143: 12781.0s.
# === Cycle 143 (t=12781.0s) ===
# Vehicles currently in simulation: 128
# Fixed split=0.50, C=90.0, O1=0.350, O2=0.171, score=0.296
#
# Time passed at cycle 144: 12871.0s.
# === Cycle 144 (t=12871.0s) ===
# Vehicles currently in simulation: 125
# Fixed split=0.50, C=90.0, O1=0.367, O2=0.192, score=0.314
#
# Time passed at cycle 145: 12961.0s.
# === Cycle 145 (t=12961.0s) ===
# Vehicles currently in simulation: 119
# Fixed split=0.50, C=90.0, O1=0.310, O2=0.106, score=0.249
#
# Time passed at cycle 146: 13051.0s.
# === Cycle 146 (t=13051.0s) ===
# Vehicles currently in simulation: 115
# Fixed split=0.50, C=90.0, O1=0.297, O2=0.157, score=0.255
#
# Time passed at cycle 147: 13141.0s.
# === Cycle 147 (t=13141.0s) ===
# Vehicles currently in simulation: 109
# Fixed split=0.50, C=90.0, O1=0.346, O2=0.092, score=0.270
#
# Time passed at cycle 148: 13231.0s.
# === Cycle 148 (t=13231.0s) ===
# Vehicles currently in simulation: 111
# Fixed split=0.50, C=90.0, O1=0.363, O2=0.487, score=0.400
#
# Time passed at cycle 149: 13321.0s.
# === Cycle 149 (t=13321.0s) ===
# Vehicles currently in simulation: 126
# Fixed split=0.50, C=90.0, O1=0.378, O2=0.248, score=0.339
#
# Time passed at cycle 150: 13411.0s.
# === Cycle 150 (t=13411.0s) ===
# Vehicles currently in simulation: 115
# Fixed split=0.50, C=90.0, O1=0.340, O2=0.160, score=0.286
#
# Time passed at cycle 151: 13501.0s.
# === Cycle 151 (t=13501.0s) ===
# Vehicles currently in simulation: 99
# Fixed split=0.50, C=90.0, O1=0.372, O2=0.325, score=0.358
#
# Time passed at cycle 152: 13591.0s.
# === Cycle 152 (t=13591.0s) ===
# Vehicles currently in simulation: 92
# Fixed split=0.50, C=90.0, O1=0.271, O2=0.014, score=0.194
#
# Time passed at cycle 153: 13681.0s.
# === Cycle 153 (t=13681.0s) ===
# Vehicles currently in simulation: 76
# Fixed split=0.50, C=90.0, O1=0.299, O2=0.289, score=0.296
#
# Time passed at cycle 154: 13771.0s.
# === Cycle 154 (t=13771.0s) ===
# Vehicles currently in simulation: 70
# Fixed split=0.50, C=90.0, O1=0.400, O2=0.234, score=0.350
#
# Time passed at cycle 155: 13861.0s.
# === Cycle 155 (t=13861.0s) ===
# Vehicles currently in simulation: 83
# Fixed split=0.50, C=90.0, O1=0.371, O2=0.272, score=0.341
#
# Time passed at cycle 156: 13951.0s.
# === Cycle 156 (t=13951.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.316, O2=0.537, score=0.382
#
# Time passed at cycle 157: 14041.0s.
# === Cycle 157 (t=14041.0s) ===
# Vehicles currently in simulation: 71
# Fixed split=0.50, C=90.0, O1=0.400, O2=0.165, score=0.329
#
# Time passed at cycle 158: 14131.0s.
# === Cycle 158 (t=14131.0s) ===
# Vehicles currently in simulation: 76
# Fixed split=0.50, C=90.0, O1=0.356, O2=0.149, score=0.294
#
# Time passed at cycle 159: 14221.0s.
# === Cycle 159 (t=14221.0s) ===
# Vehicles currently in simulation: 75
# Fixed split=0.50, C=90.0, O1=0.360, O2=0.325, score=0.350
#
# Time passed at cycle 160: 14311.0s.
# === Cycle 160 (t=14311.0s) ===
# Vehicles currently in simulation: 66
# Fixed split=0.50, C=90.0, O1=0.246, O2=0.013, score=0.176
#
# Time passed at cycle 161: 14401.0s.
# === Cycle 161 (t=14401.0s) ===
# Vehicles currently in simulation: 67
# Fixed split=0.50, C=90.0, O1=0.254, O2=0.100, score=0.208
#
# Time passed at cycle 162: 14491.0s.
# === Cycle 162 (t=14491.0s) ===
# Vehicles currently in simulation: 63
# Fixed split=0.50, C=90.0, O1=0.325, O2=0.346, score=0.331
#
# Time passed at cycle 163: 14581.0s.
# === Cycle 163 (t=14581.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.285, O2=0.103, score=0.231
#
# Time passed at cycle 164: 14671.0s.
# === Cycle 164 (t=14671.0s) ===
# Vehicles currently in simulation: 78
# Fixed split=0.50, C=90.0, O1=0.324, O2=0.115, score=0.261
#
# Time passed at cycle 165: 14761.0s.
# === Cycle 165 (t=14761.0s) ===
# Vehicles currently in simulation: 71
# Fixed split=0.50, C=90.0, O1=0.267, O2=0.066, score=0.207
#
# Time passed at cycle 166: 14851.0s.
# === Cycle 166 (t=14851.0s) ===
# Vehicles currently in simulation: 67
# Fixed split=0.50, C=90.0, O1=0.250, O2=0.195, score=0.234
#
# Time passed at cycle 167: 14941.0s.
# === Cycle 167 (t=14941.0s) ===
# Vehicles currently in simulation: 68
# Fixed split=0.50, C=90.0, O1=0.298, O2=0.113, score=0.243
#
# Time passed at cycle 168: 15031.0s.
# === Cycle 168 (t=15031.0s) ===
# Vehicles currently in simulation: 71
# Fixed split=0.50, C=90.0, O1=0.326, O2=0.145, score=0.272
#
# Time passed at cycle 169: 15121.0s.
# === Cycle 169 (t=15121.0s) ===
# Vehicles currently in simulation: 69
# Fixed split=0.50, C=90.0, O1=0.337, O2=0.118, score=0.272
#
# Time passed at cycle 170: 15211.0s.
# === Cycle 170 (t=15211.0s) ===
# Vehicles currently in simulation: 68
# Fixed split=0.50, C=90.0, O1=0.279, O2=0.059, score=0.213
#
# Time passed at cycle 171: 15301.0s.
# === Cycle 171 (t=15301.0s) ===
# Vehicles currently in simulation: 66
# Fixed split=0.50, C=90.0, O1=0.232, O2=0.284, score=0.248
#
# Time passed at cycle 172: 15391.0s.
# === Cycle 172 (t=15391.0s) ===
# Vehicles currently in simulation: 63
# Fixed split=0.50, C=90.0, O1=0.371, O2=0.194, score=0.318
#
# Time passed at cycle 173: 15481.0s.
# === Cycle 173 (t=15481.0s) ===
# Vehicles currently in simulation: 86
# Fixed split=0.50, C=90.0, O1=0.340, O2=0.079, score=0.262
#
# Time passed at cycle 174: 15571.0s.
# === Cycle 174 (t=15571.0s) ===
# Vehicles currently in simulation: 89
# Fixed split=0.50, C=90.0, O1=0.331, O2=0.121, score=0.268
#
# Time passed at cycle 175: 15661.0s.
# === Cycle 175 (t=15661.0s) ===
# Vehicles currently in simulation: 80
# Fixed split=0.50, C=90.0, O1=0.282, O2=0.124, score=0.235
#
# Time passed at cycle 176: 15751.0s.
# === Cycle 176 (t=15751.0s) ===
# Vehicles currently in simulation: 64
# Fixed split=0.50, C=90.0, O1=0.238, O2=0.014, score=0.170
#
# Time passed at cycle 177: 15841.0s.
# === Cycle 177 (t=15841.0s) ===
# Vehicles currently in simulation: 67
# Fixed split=0.50, C=90.0, O1=0.324, O2=0.511, score=0.380
#
# Time passed at cycle 178: 15931.0s.
# === Cycle 178 (t=15931.0s) ===
# Vehicles currently in simulation: 72
# Fixed split=0.50, C=90.0, O1=0.364, O2=0.215, score=0.319
#
# Time passed at cycle 179: 16021.0s.
# === Cycle 179 (t=16021.0s) ===
# Vehicles currently in simulation: 75
# Fixed split=0.50, C=90.0, O1=0.436, O2=0.154, score=0.351
#
# Time passed at cycle 180: 16111.0s.
# === Cycle 180 (t=16111.0s) ===
# Vehicles currently in simulation: 87
# Fixed split=0.50, C=90.0, O1=0.377, O2=0.251, score=0.339
#
# Time passed at cycle 181: 16201.0s.
# ❌ No more vehicles at cycle 181, stopping early.
#
# ✅ Baseline completed — results saved to logs/traffic_baseline_summary_20251209_102108.csv

# %%
from src import config
from src.utils import visualize_pow_results

visualize_pow_results(log_dir=config.LOG_DIR, prefix="traffic_baseline", suffix="20251209_102108")
# Out:
# Loaded 180 cycles from logs/traffic_baseline_summary_20251209_102108.csv
# === Summary statistics ===
#            s      C       O1       O2  score_best  elapsed_s
# count  180.0  180.0  180.000  180.000     180.000      180.0
# mean     0.5   90.0    0.353    0.283       0.332        0.0
# std      0.0    0.0    0.194    0.191       0.168        0.0
# min      0.5   90.0    0.075    0.000       0.072        0.0
# 25%      0.5   90.0    0.197    0.118       0.218        0.0
# 50%      0.5   90.0    0.327    0.260       0.293        0.0
# 75%      0.5   90.0    0.430    0.402       0.401        0.0
# max      0.5   90.0    1.000    0.930       0.897        0.0
#
# ✅  Average runtime per DE optimization: 0.00s
# ✅ Visualization complete — core PoW evidence generated.

# %%
from src.utils import compare_logs_by_time

compare_logs_by_time(baseline_prefix='traffic_baseline', de_prefix ='traffic_MLP', de_suffix='20251209_101741', baseline_suffix='20251209_102108')

# %%
from src.utils import compare_score_best

compare_score_best(baseline_prefix='traffic_baseline', de_prefix ='traffic_MLP', de_suffix='20251209_101741', baseline_suffix='20251209_102108')
# Out:
# Average DE score_best: 0.2422
# Average Baseline score_best: 0.3320
# Δ Improvement: -0.0897 (-27.03% change)
# ✅ DE improves over Baseline.
