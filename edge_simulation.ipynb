# %%
# %pip install onnxruntime onnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 35.4 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 42.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [onnx]1/2 [onnx]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from src import config
from src.benchmark_edge import seed_edge_benchmark


times = seed_edge_benchmark(
    feature_csv=config.DATASET_PATH,
    threads=1,
    warmup_iters=200,
    timed_iters=2000,
)
# Out:
# === Edge Benchmark (ONNX, End-to-End) ===
# Threads=1, Warmup=200, Iters=2000
# Features: ['q_NS_ema', 'q_EW_ema', 'ns_delay_prev', 'ew_delay_prev', 'prev_split', 'prev_cycle']
# Targets : ['s_star', 'C_star']
# ...
