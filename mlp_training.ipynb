# %%
# %pip install numpy pandas scikit-learn

# %%
# %pip install torch --index-url https://download.pytorch.org/whl/cu121

# %%
from src.train_de_mlp import train_de_ml


train_de_ml()
# Out:
# Using device: cuda
# Epoch 001  Val Loss = 0.972430
# Epoch 002  Val Loss = 0.958855
# Epoch 003  Val Loss = 0.953861
# Epoch 004  Val Loss = 0.945747
# Epoch 005  Val Loss = 0.946556
# Epoch 006  Val Loss = 0.939763
# Epoch 007  Val Loss = 0.942230
# Epoch 008  Val Loss = 0.938982
# Epoch 009  Val Loss = 0.937333
# Epoch 010  Val Loss = 0.935573
# Epoch 011  Val Loss = 0.940931
# Epoch 012  Val Loss = 0.939875
# Epoch 013  Val Loss = 0.934132
# Epoch 014  Val Loss = 0.940507
# Epoch 015  Val Loss = 0.935535
# Epoch 016  Val Loss = 0.931075
# Epoch 017  Val Loss = 0.933504
# Epoch 018  Val Loss = 0.933434
# Epoch 019  Val Loss = 0.928992
# Epoch 020  Val Loss = 0.933362
# Epoch 021  Val Loss = 0.932147
# Epoch 022  Val Loss = 0.928459
# Epoch 023  Val Loss = 0.936433
# Epoch 024  Val Loss = 0.930022
# Epoch 025  Val Loss = 0.935351
# Epoch 026  Val Loss = 0.933608
# Epoch 027  Val Loss = 0.929791
# Epoch 028  Val Loss = 0.926999
# Epoch 029  Val Loss = 0.923960
# Epoch 030  Val Loss = 0.926571
# Epoch 031  Val Loss = 0.926028
# Epoch 032  Val Loss = 0.923180
# Epoch 033  Val Loss = 0.924063
# Epoch 034  Val Loss = 0.926265
# Epoch 035  Val Loss = 0.928703
# Epoch 036  Val Loss = 0.929305
# Epoch 037  Val Loss = 0.927331
# Epoch 038  Val Loss = 0.926983
# Epoch 039  Val Loss = 0.925895
# Epoch 040  Val Loss = 0.923324
# Epoch 041  Val Loss = 0.929479
# Epoch 042  Val Loss = 0.924687
# Epoch 043  Val Loss = 0.924961
# Epoch 044  Val Loss = 0.916784
# Epoch 045  Val Loss = 0.924560
# Epoch 046  Val Loss = 0.924832
# Epoch 047  Val Loss = 0.927330
# Epoch 048  Val Loss = 0.928010
# Epoch 049  Val Loss = 0.921403
# Epoch 050  Val Loss = 0.932197
# Epoch 051  Val Loss = 0.926471
# Epoch 052  Val Loss = 0.921083
# Epoch 053  Val Loss = 0.926594
# Epoch 054  Val Loss = 0.922070
# Epoch 055  Val Loss = 0.923412
# Epoch 056  Val Loss = 0.922227
# Epoch 057  Val Loss = 0.924419
# Epoch 058  Val Loss = 0.922612
# Epoch 059  Val Loss = 0.921084
# Epoch 060  Val Loss = 0.925391
# Epoch 061  Val Loss = 0.924748
# Epoch 062  Val Loss = 0.922081
# Epoch 063  Val Loss = 0.919269
# Epoch 064  Val Loss = 0.922036
# Early stopping at epoch 64
# Best val loss: 0.916784
#
# === Test Metrics ===
# mae_s_star: 0.053776
# mae_C_star: 13.534550
# rmse_s_star: 0.069768
# rmse_C_star: 16.193077
# num_test: 865
#
# Saved model to models/mlp_de_teacher_model.pth
