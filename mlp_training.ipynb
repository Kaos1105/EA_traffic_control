# %%
# %pip install numpy pandas scikit-learn

# %%
# %pip install torch --index-url https://download.pytorch.org/whl/cu121

# %%
from src.train_de_mlp import train_de_ml

train_de_ml()
# Out:
# Using device: cuda
# Epoch 001  Val Loss = 0.996381
# Epoch 002  Val Loss = 0.987850
# Epoch 003  Val Loss = 0.987078
# Epoch 004  Val Loss = 0.980376
# Epoch 005  Val Loss = 0.976478
# Epoch 006  Val Loss = 0.974541
# Epoch 007  Val Loss = 0.967139
# Epoch 008  Val Loss = 0.969622
# Epoch 009  Val Loss = 0.969301
# Epoch 010  Val Loss = 0.967203
# Epoch 011  Val Loss = 0.963522
# Epoch 012  Val Loss = 0.965741
# Epoch 013  Val Loss = 0.959221
# Epoch 014  Val Loss = 0.965398
# Epoch 015  Val Loss = 0.966944
# Epoch 016  Val Loss = 0.960518
# Epoch 017  Val Loss = 0.960091
# Epoch 018  Val Loss = 0.963262
# Epoch 019  Val Loss = 0.956871
# Epoch 020  Val Loss = 0.961204
# Epoch 021  Val Loss = 0.957290
# Epoch 022  Val Loss = 0.961955
# Epoch 023  Val Loss = 0.958699
# Epoch 024  Val Loss = 0.958035
# Epoch 025  Val Loss = 0.956274
# Epoch 026  Val Loss = 0.960390
# Epoch 027  Val Loss = 0.958429
# Epoch 028  Val Loss = 0.958015
# Epoch 029  Val Loss = 0.955906
# Epoch 030  Val Loss = 0.957822
# Epoch 031  Val Loss = 0.957720
# Epoch 032  Val Loss = 0.956436
# Epoch 033  Val Loss = 0.957675
# Epoch 034  Val Loss = 0.954130
# Epoch 035  Val Loss = 0.956900
# Epoch 036  Val Loss = 0.955384
# Epoch 037  Val Loss = 0.956684
# Epoch 038  Val Loss = 0.959034
# Epoch 039  Val Loss = 0.961099
# Epoch 040  Val Loss = 0.951142
# Epoch 041  Val Loss = 0.953533
# Epoch 042  Val Loss = 0.957401
# Epoch 043  Val Loss = 0.954865
# Epoch 044  Val Loss = 0.957123
# Epoch 045  Val Loss = 0.956285
# Epoch 046  Val Loss = 0.956962
# Epoch 047  Val Loss = 0.959995
# Epoch 048  Val Loss = 0.957684
# Epoch 049  Val Loss = 0.959961
# Epoch 050  Val Loss = 0.952713
# Epoch 051  Val Loss = 0.954591
# Epoch 052  Val Loss = 0.957511
# Epoch 053  Val Loss = 0.954239
# Epoch 054  Val Loss = 0.952232
# Epoch 055  Val Loss = 0.955838
# Epoch 056  Val Loss = 0.954513
# Epoch 057  Val Loss = 0.956673
# Epoch 058  Val Loss = 0.950635
# Epoch 059  Val Loss = 0.957645
# Epoch 060  Val Loss = 0.957918
# Epoch 061  Val Loss = 0.954549
# Epoch 062  Val Loss = 0.950613
# Epoch 063  Val Loss = 0.955917
# Epoch 064  Val Loss = 0.952730
# Epoch 065  Val Loss = 0.953542
# Epoch 066  Val Loss = 0.956018
# Epoch 067  Val Loss = 0.950370
# Epoch 068  Val Loss = 0.951107
# Epoch 069  Val Loss = 0.953261
# Epoch 070  Val Loss = 0.952564
# Epoch 071  Val Loss = 0.950351
# Epoch 072  Val Loss = 0.958737
# Epoch 073  Val Loss = 0.956541
# Epoch 074  Val Loss = 0.955850
# Epoch 075  Val Loss = 0.957211
# Epoch 076  Val Loss = 0.957289
# Epoch 077  Val Loss = 0.955912
# Epoch 078  Val Loss = 0.956810
# Epoch 079  Val Loss = 0.958557
# Epoch 080  Val Loss = 0.957610
# Epoch 081  Val Loss = 0.956447
# Epoch 082  Val Loss = 0.953512
# Epoch 083  Val Loss = 0.953773
# Epoch 084  Val Loss = 0.953272
# Epoch 085  Val Loss = 0.958768
# Epoch 086  Val Loss = 0.957963
# Epoch 087  Val Loss = 0.958217
# Epoch 088  Val Loss = 0.955556
# Epoch 089  Val Loss = 0.954605
# Epoch 090  Val Loss = 0.955915
# Epoch 091  Val Loss = 0.960307
# Early stopping at epoch 91
# Best val loss: 0.950351
#
# === Test Metrics (Raw) ===
# MAE s_star:  0.056581
# RMSE s_star: 0.071834
# MAE C_star:  13.469848 seconds
# RMSE C_star: 16.131479 seconds
#
# === Human Readable Interpretation ===
# s_star MAE: 5.66 percentage points
# C_star MAE: 13.47 seconds
# C_star MAE % of Mean Cycle: 15.95%
#
# Saved model to models/mlp_de_teacher_model.pth
