# %%
# %pip install numpy pandas scikit-learn

# %%
# %pip install torch --index-url https://download.pytorch.org/whl/cu121

# %%
from src.train_de_mlp import train_de_ml

train_de_ml()
# Out:
# Using device: cuda
# Epoch 001  Val Loss = 0.977917
# Epoch 002  Val Loss = 0.966521
# Epoch 003  Val Loss = 0.955691
# Epoch 004  Val Loss = 0.952460
# Epoch 005  Val Loss = 0.950248
# Epoch 006  Val Loss = 0.949353
# Epoch 007  Val Loss = 0.947036
# Epoch 008  Val Loss = 0.943340
# Epoch 009  Val Loss = 0.948236
# Epoch 010  Val Loss = 0.941770
# Epoch 011  Val Loss = 0.938529
# Epoch 012  Val Loss = 0.942684
# Epoch 013  Val Loss = 0.942644
# Epoch 014  Val Loss = 0.937072
# Epoch 015  Val Loss = 0.936302
# Epoch 016  Val Loss = 0.935887
# Epoch 017  Val Loss = 0.937982
# Epoch 018  Val Loss = 0.938867
# Epoch 019  Val Loss = 0.939453
# Epoch 020  Val Loss = 0.935347
# Epoch 021  Val Loss = 0.935916
# Epoch 022  Val Loss = 0.937836
# Epoch 023  Val Loss = 0.932738
# Epoch 024  Val Loss = 0.932878
# Epoch 025  Val Loss = 0.933620
# Epoch 026  Val Loss = 0.930977
# Epoch 027  Val Loss = 0.935413
# Epoch 028  Val Loss = 0.931310
# Epoch 029  Val Loss = 0.929768
# ...
